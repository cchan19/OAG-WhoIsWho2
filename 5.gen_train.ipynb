# %%
import pandas as pd
import numpy as np
import os
import sys
from collections import OrderedDict
import json
import random
random.seed(42)
np.random.seed(42)

# %%
import pickle
with open('./pkl/author_name_map.pkl', 'rb') as file:
    author_name_map = pickle.load(file)
with open('./pkl/author_org_map.pkl', 'rb') as file:
    author_org_map = pickle.load(file)

# %%
whole_author_name_paper_ids = pd.read_pickle('./pkl/whole_author_name_paper_ids.pkl')
train_author_name_ids = pd.read_pickle('./pkl/train_author_name_ids.pkl')
valid_data = pd.read_pickle('./pkl/valid_data.pkl')

# %%
print('valid: ', len(set(valid_data['author_name'])))
print('train: ', len(set(train_author_name_ids['author_name'])))
print('whole: ', len(set(whole_author_name_paper_ids['author_name'])))
print('-'*60)
print('valid & train: ', len(set(train_author_name_ids['author_name']) & set(valid_data['author_name'])))
print('whole & valid: ', len(set(whole_author_name_paper_ids['author_name']) & set(valid_data['author_name'])))
print('whole & train: ', len(set(whole_author_name_paper_ids['author_name']) & set(train_author_name_ids['author_name'])))
# Out:
# valid:  36
# train:  221
# whole:  320
# ------------------------------------------------------------
# valid & train:  0
# whole & valid:  36
# whole & train:  220

# %%
train_author_paper_ids = pd.read_pickle('./pkl/train_author_paper_ids.pkl')

# %%
whole_author_name_paper_ids
# Out:
#       author_id    author_name  \
# 0      004mBKh6  changsheng_li
# 1      008b5hIc   yuanyuan_liu
# 2      00BAgHFr          xi_li
# 3      00M93JDI    weiping_cai
# 4      00ShLPmg      hong_xiao
# 5      00spmMI1       feng_liu
# 6      016kCnvN       bo_zhang
# 7      019rPybm       feng_zhu
# 8      01B6P0IC       liu_yang
# 9      01Ep2mqq      ming_chen
# 10     01hQUc2n       jun_chen
# 11     01lDTk6t       jun_chen
# 12     01mFX99n       feng_gao
# 13     01sROJ1w      chao_yuan
# 14     021S5Dgp        yong_yu
# 15     023zvSlv       feng_zhu
# 16     028kPXFb       c_c_wang
# 17     0296NTh7          s_liu
# 18     02E3zQhR      bing_zhou
# 19     02Rfc8WQ       xue_wang
# 20     02TCy2lh          li_ma
# 21     02n9yUf0       feng_liu
# 22     02nOtsqB   yuanyuan_liu
# 23     02xCc1XW           z_wu
# 24     02yiIOce       ji_zhang
# 25     0342Xnsp       bo_jiang
# 26     0372SRFC         y_feng
# 27     03Lueicz       jun_chen
# 28     03TeIKhe       bo_zhang
# 29     03UZ6yih         jin_xu
# ...         ...            ...
# 25881  zvgcgSxN     gang_zhang
# 25882  zvp9lgzh   heqing_huang
# 25883  zwE0i8ky     gang_zhang
# 25884  zwIvP0Lg       zhi_wang
# 25885  zwZWax87      yan_liang
# 25886  zwc3vzOj      fang_wang
# 25887  zwkRwf9E         xia_li
# 25888  zwoXJ9Qq       xue_wang
# 25889  zwvOoECx      yan_liang
# 25890  zx3vQrQz    shuai_zhang
# 25891  zx8Vmnuk        lei_shi
# 25892  zxK5YmBD          xi_li
# 25893  zxSYNSa5        yan_gao
# 25894  zxSzxjZF      xiang_gao
# 25895  zxVyrRrh      jing_chen
# 25896  zxYpjWnI         bin_hu
# 25897  zxiEiruf    jianjun_liu
# 25898  zy1apjjm       lan_wang
# 25899  zy9MbnjV      jing_chen
# 25900  zyEX1J1i         jia_li
# 25901  zyVieHr3           z_wu
# 25902  zyvyUJsN     xiang_wang
# 25903  zyz7znyO         xin_li
# 25904  zzH2p2Vp      ming_chen
# 25905  zzQ9wlSi         xin_wu
# 25906  zzSkQtmA      hong_zhao
# 25907  zziR8f6A      qing_yang
# 25908  zzjar8aW       feng_liu
# 25909  zzqI8ndQ       jun_chen
# 25910  zzzC8lFa          s_liu
#
#                                                paper_ids
# 0      [lRl7m2tU, 1vUnZLES, 5IbEOTRh, dVAKsHla, TY0MY...
# 1                                             [nPuf0kYs]
# 2                         [TuEkjf5i, kn6wo3ot, 0f2awX7U]
# 3      [mHDfYkqE, RWISo90R, FSsnfI0X, 4U4GvMmc, Yh45T...
# 4      [inFGp3mc, uyJus3zu, o6poFI1m, KvHObx7O, vg64a...
# 5               [10ykVAH3, wsAMQuWh, yIfqzYkw, 6xmeeYQX]
# 6               [JPpvkljc, iu27HXuu, sR7LojbI, FyxOvKTv]
# 7                                             [29jyH3ur]
# 8                                             [qp9i4bCq]
# 9               [9ZcJh2w1, iTcHhzjY, uJFwhMlE, KVivqYYz]
# 10     [7YMwONqR, yEZy71Fe, BxKTAQSv, Pq6XTTK2, JI8sN...
# 11     [Xf0dDqG1, UFHYzNIv, ftE9NcbE, rArWxP9y, AwWEa...
# 12     [uxjp6tWC, T7tLIwNW, F7hb3v5x, 0GnLPTwM, LNCyT...
# 13     [XtP59vj5, q8Eatm6g, vZrY3N4X, EdZwL9RG, IPsBy...
# 14                                            [kc4SsvJ3]
# 15                                            [FmFb9Ofo]
# 16                                            [K99mpzHC]
# 17                                            [iRlhVbCa]
# 18     [XiQrkDdT, FB2VYgAg, 8fNqrsNU, zTgwVbF1, PGW3F...
# 19              [e7sknJaf, iQLr1A6P, eJQMePQR, O3YEZmSv]
# 20                                            [dD99Byu5]
# 21     [V1mqNXyi, Bf6Sf4nl, 4g7bl0Dz, hKIMx2wH, 11fG5...
# 22                                            [7ImkX65o]
# 23                                            [NmXyhnfP]
# 24                        [S81GprJB, PuCLCyTt, TF9z5eGU]
# 25                                            [ZcpFBTgC]
# 26                                            [TkFBEAHN]
# 27     [bYmPkcqj, QXuD9z72, OsO8sBkr, t3y7e6m8, iQyiM...
# 28     [Rkyw4g4m, EzROIpwY, lpG04dfk, aYZcyb7i, b2kbZ...
# 29     [XlWkLtyl, nr4DFRqD, 1C1W6FHc, LOcg29Jj, 107AB...
# ...                                                  ...
# 25881                                         [cE4ImAWZ]
# 25882                               [ljGJaE15, 5vF3lSig]
# 25883                                         [VnSr0KEP]
# 25884                               [eqzrsw3L, VeCzOrEI]
# 25885                                         [7dMX8J8j]
# 25886  [HjupoFtI, 4j7pO38c, RwX3wmg2, Ds6wOKqT, e9Aj4...
# 25887           [73aPikcc, dy8RDnlm, agwIaoIJ, Lgl9Lz3X]
# 25888                                         [IxVcnc21]
# 25889                                         [cc9zbzL6]
# 25890  [p9oTeXll, QlocW0SV, tx2AuGOk, jLXLkpnt, POyQ3...
# 25891  [GTEsev9V, fsA3GIGf, MY2i2FZq, Xh8Qlhoj, nsfMF...
# 25892                                         [OIarJAVW]
# 25893  [iAf4eeck, fQMU9IrO, 4WjMrv63, oc6KuyaR, a08Hv...
# 25894                     [y6Jaiinp, 91kt8fUH, GLp1LugE]
# 25895                     [jnAS3yUI, Gih9m1F2, nf1fqw86]
# 25896  [SZoSglzO, JhXJFxDp, F5IaJRZ3, AYyMe6E6, kPRP1...
# 25897  [TYvXnVln, HHzfcYUI, 5AP0Fy2q, LJQ0nyQ1, Eeww9...
# 25898                                         [Ol2QgXuM]
# 25899                     [RJCtHATb, aaFeydiw, CvZj4nUs]
# 25900  [ESq7xQCm, 4m0FyGse, ECuAF6pn, Bkru0l4b, NXjJ2...
# 25901                     9dBLEp, bMCJrwZK, 9JesopqP]
# 25902                                         [FIO3mXov]
# 25903  [yoBRAmDd, eyE3mKR1, 7Ec8sQQA, vkXvnPPB, N2vUg...
# 25904                                         [vfPmkouB]
# 25905                                         [ODL3iqRx]
# 25906  [UXN2DXa4, AAPSkLON, CcR2FVZk, YDU0L4Tk, 8EZfr...
# 25907                                         [jlOoesGq]
# 25908  [my1HC700, i9JjXbJx, VPaaM7Et, xzyTre1z, R0UfJ...
# 25909  [ubfwavT4, mTFn2lPv, OpxbhSrg, wmbCUMP0, 0wP4N...
# 25910                                         [9lrTX6cQ]
#
# [25911 rows x 3 columns]

# %%
train_author_name_ids
# Out:
#              author_name                                         author_ids
# 0                 li_guo  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...
# 1                bo_shen  [dMMuUSbg, r91hXBvS, kk7noJ6Z, S0KddW6h, kUxuc...
# 2                di_wang  [2o9S3IgV, uzBq8AY4, 7NLyk3Bt, kYTys3CU, 3XCRz...
# 3              long_wang  [uKI2RE1e, K2JAovvb, vWlBGAUA, FLgn5LLT, 7bIVU...
# 4               qiang_xu  [IYKUkSRi, W32PyUka, oBEDBnzr, NDYPRF7h, 4pv4t...
# 5             xiang_wang  [cykm1BJw, stdvmffN, mrsIu8Ho, 4lLJsaTA, 5ig0F...
# 6          changming_liu  [Vk5pmdTQ, heYnUfuY, o2chpvWn, dRDBdt8h, cwrrT...
# 7           kenji_kaneko  [HnK9fnTV, 7RU1YNLQ, CL77nXuo, WHPZ6PXO, 6B9H3...
# 8            guohua_chen  [GdEw4XzH, fXl8TXkC, tvMgxeH8, 0pLF5rFp, 5FZNH...
# 9                hai_jin  [DonOpobk, 25yQj8PF, UplTM9r1, xhbXfLSi, maXhU...
# 10                jia_li  [ADwWYT0i, RU40uLrp, hbN0CZZi, EEL0HNsz, UU9yw...
# 11           guoliang_li  [sxKCpVzv, 2zvX0amO, aDMsfOWG, H25P9a8Q, Rusti...
# 12              lan_wang  [ZFUB0P91, Gtt8Psva, otNxrb8y, l0xqBcmT, seXHY...
# 13   alessandro_giuliani  [fTF8ReaC, hgAzrerZ, JlG4ALNx, mIkonUWw, hbGAG...
# 14              jiang_he  [flshajOb, Rb62sNM9, B548d7Ek, Fku2G1Tk, 6qEIg...
# 15             xiang_gao  [2iVrut0V, cavQuWAQ, uMElkuOk, Li5ZnxXl, tEhQg...
# 16           jianping_wu  [1pkuc8Ic, 3THsUyD9, at27cJUx, jt32rPVO, 16Hyz...
# 17              peng_shi  [edMdy0SG, GLHXrzgg, klpPZTP1, bq1EtMlz, GFkOK...
# 18               feng_wu  [d8fxL9lF, UAaWcQKO, yOwk0vIP, EP9wu7MT, c2R21...
# 19              jing_zhu  [np1q8IBz, 1hvqTfUD, 8CTAXCXJ, Sc3T0YNW, UeUzf...
# 20        xiaoyang_zhang  [cej2LsRS, aMRVKIqF, HUYWA0a4, KzTGJGb8, T8aML...
# 21               mei_han  [6VBFRgpL, UAecUaTz, RbVFwGuZ, 84x84G1o, NqPkR...
# 22          jianhua_shen  [KlCfxkxF, ZoFiChpZ, Zc7elbp6, UT6ZaTX8, 2IaHd...
# 23             hong_xiao  [KUGcNQmo, xesBgqia, VlzADtvb, 29HFs22F, odk7o...
# 24             qing_yang  [Em2A4tS1, 0WlmdXBO, UxCY5YpO, Lp3Vz2b4, oE3TL...
# 25         makoto_sasaki  [w0SzBj9c, UcyJtHGs, 26AaywtR, fsutuuw8, Iw1vW...
# 26              feng_gao  [UXpTXfbE, hWA4ptRW, Ibc5BWCr, 2bNaxaKq, YGaTF...
# 27               d_zhang  [Wtx5Pe3T, lLXmBCaA, dkwkbnGS, d22NNg4G, 4eSU5...
# 28             akira_ono  [7ZlFaYQq, pn65uNo2, zHlJV1dg, Gbike6iR, 8DdHg...
# 29             hong_yang  [SCPI8IFH, fFeOSsqX, v0UT56ZP, jIhPOaEl, GVfHi...
# ..                   ...                                                ...
# 191         wenjun_zheng           [MSQLtx09, nST9Jy4s, K91ZSBEb, 2WGW1CPk]
# 192             bo_jiang  [k23TUMWC, eQ5P0mJE, i9YgTtHt, 43fMi2Bu, eaYRF...
# 193    hideaki_takahashi           [QMHRVODI, O80OAkZP, ArKgVx4V, spdYqzMp]
# 194               kai_yu  [4jKFUfvP, Pz9zJb6B, yd6hwUs9, eOPMlL1o, IqvYX...
# 195        changsheng_li  [M6jbsS5p, CV9pyIPZ, Zsga7lc2, 8tecoUxC, yJbqq...
# 196            peng_gong  [KUz2Gid6, 5lgNUgkq, NTXzddqt, ge9brGo8, aJAzq...
# 197           hongbo_sun  [qTBWQjvI, bmk95xdp, xNIzK3vN, Y0LCW3FI, 1CSED...
# 198              jie_yin  [IEHBCWYU, YlwFZpq2, 2PilAhiy, lsmPFG01, Z6tNx...
# 199                 z_wu  [801Q930X, hiHcfXhi, GJPMT3x6, qAGT1hte, SJnpd...
# 200             zhi_wang  [EDjjiDwo, 3xFysgal, fG35e58k, JpBN44nj, XomTX...
# 201          lixia_zhang  [op5dXmcv, c0fsPU7c, AD8qgWVT, lsIB0Zyv, OfBS3...
# 202            qiong_luo  [plxoreN7, XjplHrA1, BoOs9WKi, ndioyFvi, McTvK...
# 203                s_liu  [ZzZLKrQI, LV3rKG2W, QZcbbuuX, qBeSO0B6, xg46I...
# 204               jin_li  [hVnOHMSk, GSFaPxRC, BjuHiUeF, xM2HTWE6, H9hEi...
# 205              jing_li  [2U43ERuM, r5jWVGAK, NylRCM27, aOSyFGbj, KQMMR...
# 206               c_yang  [W8AvSvlM, MliJWC7p, SJ6t5Pb7, rQfQ5qC5, QamPG...
# 207             yuxi_liu  [isjfuWsC, VrBVSm2b, 7rKHVWto, gBgDC4P3, XPdsJ...
# 208           bing_zhang  [jEYNF9a7, n7uT775d, L9nf6sgD, 45sR4K8u, yVlJQ...
# 209             j_y_wang  [zcv2dkx9, mTbIvGzk, honpCAUb, zb8KUWLP, bjtgi...
# 210            sheng_dai           [M8HrhNRb, 7iCMQilA, Q6G1hMn4, gxf3ctF0]
# 211              jie_luo  [6eRoLE9n, SpvWAoRX, BTe5T3H4, p2LthVSJ, c5sYu...
# 212               bin_hu  [9z2Mnvr0, Py04Ea0N, 5nCJBOJq, 5XQlyb0T, Q3wUb...
# 213             hai_yang  [LHhM2MD4, 7WK1SvgR, F9RM8SHg, 3W3DGjzk, O2jQH...
# 214            ming_chen  [CiAQiQOM, xq4n8gBy, EufNqoTN, Grwo6hcp, JKGCM...
# 215              juan_du  [2tQVlXgA, x8gVaC1l, M5vrhWX3, 3W0mPmWi, xKAbW...
# 216      hiroaki_okamoto  [LGcWUHZe, 8mPqiOw9, FHbmL2jX, eENv2Wuh, U2IDa...
# 217             dan_wang  [Pxy7hkaf, WLncYKR0, rev1qrvb, qiadKgDB, 4j5kq...
# 218             jun_chen  [AUYRKdop, EcUVStC9, 7U2oA8Ei, 8aadbYEC, 1YTud...
# 219             bai_yang  [MiIxNg2Y, nnXl5kA9, qsAl4WGb, Mth7l53q, ZtC2S...
# 220     hiroshi_sakamoto  [vwt9Wd81, MLEuzS1T, xOEKHNxv, Ms4yXx88, VosVg...
#
# [221 rows x 2 columns]

# %%
train_author_paper_ids
# Out:
#       author_id                                          paper_ids
# 0      EShnTfSe                                         [P9a1gcvg]
# 1      sCKCrny5  [Rg5fAeTd, lJPsGNBE, er5gTz90, UG32p2zs, FTweB...
# 2      SY2FEqNj                                         [2EGB9ZLn]
# 3      XXFI1LfP  [wd3ugFQM, pYKTrEQj, ZUfWc0Zj, jMErL46k, g2a7a...
# 4      KZUHqEs8  [u1BaKbeK, 3Vez4kTb, q6I5CrjK, 4r4hJNan, WTpMs...
# 5      lcJ3cnoe                     [JGa3ayoe, YamUC6TD, 3IUjB6eO]
# 6      fDByJNym                               [xwrRFngw, iu91hRCJ]
# 7      LXHDFVWG                                         [Ly6DVUex]
# 8      EDAY9Bxa                                         [fZxFyG1K]
# 9      TjyBlvRR                                         [VOm1IioC]
# 10     OimeuzLX                                         [n6LzIFhS]
# 11     mnBTCEVw                                         [eJOFE3Jh]
# 12     KJ0R8Gf2                                         [cjB1WPRn]
# 13     vQ8nLNPX                                         [Xdh4Wvth]
# 14     O9MqKvQL                               [t18lapg8, gz5NM7eR]
# 15     kdcR2lfs           [XwdyiM5A, 8yI7Ne3Z, rS54zMYj, CprlvEix]
# 16     ZKfMoZ6f  1pU4vp, eNu10VUE, QQKOFsm9, 9fRGz1Us, UtU36...
# 17     7HtL9jKl  [bJNT1e43, m7BRnkPN, T0QaZmVv, Rq31QNs1, TVTbK...
# 18     feRN2Ze9                                         [k6RU8MBA]
# 19     OaVJcRwn                                         [ijXjpqYT]
# 20     BLDVuq8W                                         [LkM8DxZC]
# 21     mCeqcVBX  [Rua38AfY, GvJ36Ck7, t5cixJhe, xZYnIJN7, ACZ9x...
# 22     HoEFUy2X                                         [MSErtepK]
# 23     0EFqaz5F  [gxFkYKbT, ncgx26VX, MSNMRJCQ, R0EhOHO7, ukyDh...
# 24     tc7akgkH                                         [TBO7qnQt]
# 25     aFzc7mdG                                         [uc4Qm5Ke]
# 26     boNLDMdP  [kgDUK0f2, eXP1xPHJ, fIjcgCDx, EWkv51gJ, msWie...
# 27     dtiuYthw                                         [oKNSOHh0]
# 28     2FmiB5lM  [E6xJAj0L, dhp6sPrt, CPL6CInC, wusLSr2K, pdOh3...
# 29     HD66kgFI  [tdaysBqn, azZqveNS, zqmk4YLM, XHQEEpeC, bABxQ...
# ...         ...                                                ...
# 22809  ZHG5A0E1                               [av4OYhaf, ZlmsXm8w]
# 22810  5eoqmbkq                               [8S3aV5jY, F2sLODeZ]
# 22811  wNNsUQUZ                               [7kKfjfdN, pGQL2nJx]
# 22812  fTMPzHOU                               [T6XpBsue, UhV3Zxu2]
# 22813  rANZRQd1                     [gfgyrUBg, DcbsO6rR, sIrqoUcI]
# 22814  wxp3KZ6K                               [vJjd6ia4, o5vQ9qse]
# 22815  MxnQjb0L                               [0KNv0WCW, GB9q8eU7]
# 22816  kn8alOEs                     [N2Ox4qUA, pPTs5QBl, LPpCulk6]
# 22817  pRqJctfG                               [SES12SQf, LXQDPqyt]
# 22818  K1LZUGNe                     [LQJoXHm1, H0ud3mu1, qyVWxJIa]
# 22819  ktYhcDwN  [tklaetC3, da6f30GB, nihDBJyY, yEAeFpVF, hPBNK...
# 22820  P5Mlu2kv                               [3t69Gwhj, TuDLHe19]
# 22821  FbnA1sTY                     [TCvzeYBF, Zu3AhbnR, uVizKeh5]
# 22822  SzzTePJS  [0f3GeG0h, EaDflXT5, Xm8i19Q1, iOpvC7Dr, rH8Iq...
# 22823  z3cSXoHV                     [y5BaUlCX, EUygRCgd, trjuqNc3]
# 22824  fI33qhqp           [zWvxVCL2, smmBCRIv, 0UtIXIyo, ihv2AZc9]
# 22825  Sg3uQQD3                               [mXiuQKt5, 4DzMdxve]
# 22826  0r0Hx9dp                     [flV9jLqi, yy4JD5EX, 9TB95RR5]
# 22827  CQc2jjdP                               [GSJNf3ol, 1amJBWLb]
# 22828  vwt9Wd81  [ymO4V1gc, GGuKnlYB, eJgQbJrk, CDbrpav6, dX1j5...
# 22829  MLEuzS1T  [gjvLuBOr, LRtgAqWY, WskqvCyn, vtbPrVS2, m8GaF...
# 22830  xOEKHNxv  [ZqNzf8N8, aWUV2pTs, BRCvxVwg, VccHO8Lm, GhePy...
# 22831  Ms4yXx88  [qX1RU3As, MEgEOz0V, yqMplwmg, efhcLrL1, hkjcb...
# 22832  VosVgGWX  [STuVsxAA, MqLMnPYX, fevypmPc, 00vBYh5M, FQTKR...
# 22833  H7pPNJ9H  [QZUlzYXd, Svq8l5ly, HryTGsNz, onQVRgYh, I0fgv...
# 22834  Izy4g5GJ  [X6Y5JzvB, KXUghQFL, hMpb5e3i, 0clVHYAI, qW2qm...
# 22835  KCYgj45o  [7lXwlh1Q, 4SMScMPv, 4QjMUpKk, J07eYUKv, QkfHE...
# 22836  QgxWVd6S  [r6Z8eLFd, 6wqc5w05, fLUWqFzl, xM60g1AO, 13tFP...
# 22837  7mR9sXDN  [ATnbqhim, FAgWcVKY, O321nQmD, S7vtkqwZ, snIBk...
# 22838  3qn5CxG9                     [K8cvwVdF, tWNrHrcN, 4F5SbAoT]
#
# [22839 rows x 2 columns]

# %%
train_author_name_ids['author_num'] = train_author_name_ids['author_ids'].apply(len)

# %%
train_author_name_ids['author_num'].describe()
# Out:
# count    221.000000
# mean     103.343891
# std      132.716819
# min        0.000000
# 25%       15.000000
# 50%       27.000000
# 75%      216.000000
# max      588.000000
# Name: author_num, dtype: float64

# %%
train_author_name_ids = train_author_name_ids[train_author_name_ids['author_num'] >= 5]

# %%
print(train_author_name_ids['author_num'].min())
# Out:
# 5

# %%
train_author_name_ids
# Out:
#              author_name                                         author_ids  \
# 0                 li_guo  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...
# 1                bo_shen  [dMMuUSbg, r91hXBvS, kk7noJ6Z, S0KddW6h, kUxuc...
# 2                di_wang  [2o9S3IgV, uzBq8AY4, 7NLyk3Bt, kYTys3CU, 3XCRz...
# 3              long_wang  [uKI2RE1e, K2JAovvb, vWlBGAUA, FLgn5LLT, 7bIVU...
# 4               qiang_xu  [IYKUkSRi, W32PyUka, oBEDBnzr, NDYPRF7h, 4pv4t...
# 5             xiang_wang  [cykm1BJw, stdvmffN, mrsIu8Ho, 4lLJsaTA, 5ig0F...
# 6          changming_liu  [Vk5pmdTQ, heYnUfuY, o2chpvWn, dRDBdt8h, cwrrT...
# 7           kenji_kaneko  [HnK9fnTV, 7RU1YNLQ, CL77nXuo, WHPZ6PXO, 6B9H3...
# 8            guohua_chen  [GdEw4XzH, fXl8TXkC, tvMgxeH8, 0pLF5rFp, 5FZNH...
# 9                hai_jin  [DonOpobk, 25yQj8PF, UplTM9r1, xhbXfLSi, maXhU...
# 10                jia_li  [ADwWYT0i, RU40uLrp, hbN0CZZi, EEL0HNsz, UU9yw...
# 11           guoliang_li  [sxKCpVzv, 2zvX0amO, aDMsfOWG, H25P9a8Q, Rusti...
# 12              lan_wang  [ZFUB0P91, Gtt8Psva, otNxrb8y, l0xqBcmT, seXHY...
# 13   alessandro_giuliani  [fTF8ReaC, hgAzrerZ, JlG4ALNx, mIkonUWw, hbGAG...
# 14              jiang_he  [flshajOb, Rb62sNM9, B548d7Ek, Fku2G1Tk, 6qEIg...
# 15             xiang_gao  [2iVrut0V, cavQuWAQ, uMElkuOk, Li5ZnxXl, tEhQg...
# 16           jianping_wu  [1pkuc8Ic, 3THsUyD9, at27cJUx, jt32rPVO, 16Hyz...
# 17              peng_shi  [edMdy0SG, GLHXrzgg, klpPZTP1, bq1EtMlz, GFkOK...
# 18               feng_wu  [d8fxL9lF, UAaWcQKO, yOwk0vIP, EP9wu7MT, c2R21...
# 19              jing_zhu  [np1q8IBz, 1hvqTfUD, 8CTAXCXJ, Sc3T0YNW, UeUzf...
# 20        xiaoyang_zhang  [cej2LsRS, aMRVKIqF, HUYWA0a4, KzTGJGb8, T8aML...
# 21               mei_han  [6VBFRgpL, UAecUaTz, RbVFwGuZ, 84x84G1o, NqPkR...
# 22          jianhua_shen  [KlCfxkxF, ZoFiChpZ, Zc7elbp6, UT6ZaTX8, 2IaHd...
# 23             hong_xiao  [KUGcNQmo, xesBgqia, VlzADtvb, 29HFs22F, odk7o...
# 24             qing_yang  [Em2A4tS1, 0WlmdXBO, UxCY5YpO, Lp3Vz2b4, oE3TL...
# 25         makoto_sasaki  [w0SzBj9c, UcyJtHGs, 26AaywtR, fsutuuw8, Iw1vW...
# 26              feng_gao  [UXpTXfbE, hWA4ptRW, Ibc5BWCr, 2bNaxaKq, YGaTF...
# 27               d_zhang  [Wtx5Pe3T, lLXmBCaA, dkwkbnGS, d22NNg4G, 4eSU5...
# 28             akira_ono  [7ZlFaYQq, pn65uNo2, zHlJV1dg, Gbike6iR, 8DdHg...
# 29             hong_yang  [SCPI8IFH, fFeOSsqX, v0UT56ZP, jIhPOaEl, GVfHi...
# ..                   ...                                                ...
# 188           gang_zhang  [TWHG8tzb, FBXNdOiv, nlZmUZOk, 8zj324d8, RwMna...
# 189          xiaoming_li  [k1pc2mF3, kCmVVlgT, Y0p20tzQ, QCpKq0Ql, sACqc...
# 190           chunxia_li  [CwFi7j3L, rEigJoBE, BW94HSma, sBVlSGxW, SFeqm...
# 192             bo_jiang  [k23TUMWC, eQ5P0mJE, i9YgTtHt, 43fMi2Bu, eaYRF...
# 194               kai_yu  [4jKFUfvP, Pz9zJb6B, yd6hwUs9, eOPMlL1o, IqvYX...
# 195        changsheng_li  [M6jbsS5p, CV9pyIPZ, Zsga7lc2, 8tecoUxC, yJbqq...
# 196            peng_gong  [KUz2Gid6, 5lgNUgkq, NTXzddqt, ge9brGo8, aJAzq...
# 197           hongbo_sun  [qTBWQjvI, bmk95xdp, xNIzK3vN, Y0LCW3FI, 1CSED...
# 198              jie_yin  [IEHBCWYU, YlwFZpq2, 2PilAhiy, lsmPFG01, Z6tNx...
# 199                 z_wu  [801Q930X, hiHcfXhi, GJPMT3x6, qAGT1hte, SJnpd...
# 200             zhi_wang  [EDjjiDwo, 3xFysgal, fG35e58k, JpBN44nj, XomTX...
# 201          lixia_zhang  [op5dXmcv, c0fsPU7c, AD8qgWVT, lsIB0Zyv, OfBS3...
# 202            qiong_luo  [plxoreN7, XjplHrA1, BoOs9WKi, ndioyFvi, McTvK...
# 203                s_liu  [ZzZLKrQI, LV3rKG2W, QZcbbuuX, qBeSO0B6, xg46I...
# 204               jin_li  [hVnOHMSk, GSFaPxRC, BjuHiUeF, xM2HTWE6, H9hEi...
# 205              jing_li  [2U43ERuM, r5jWVGAK, NylRCM27, aOSyFGbj, KQMMR...
# 206               c_yang  [W8AvSvlM, MliJWC7p, SJ6t5Pb7, rQfQ5qC5, QamPG...
# 207             yuxi_liu  [isjfuWsC, VrBVSm2b, 7rKHVWto, gBgDC4P3, XPdsJ...
# 208           bing_zhang  [jEYNF9a7, n7uT775d, L9nf6sgD, 45sR4K8u, yVlJQ...
# 209             j_y_wang  [zcv2dkx9, mTbIvGzk, honpCAUb, zb8KUWLP, bjtgi...
# 211              jie_luo  [6eRoLE9n, SpvWAoRX, BTe5T3H4, p2LthVSJ, c5sYu...
# 212               bin_hu  [9z2Mnvr0, Py04Ea0N, 5nCJBOJq, 5XQlyb0T, Q3wUb...
# 213             hai_yang  [LHhM2MD4, 7WK1SvgR, F9RM8SHg, 3W3DGjzk, O2jQH...
# 214            ming_chen  [CiAQiQOM, xq4n8gBy, EufNqoTN, Grwo6hcp, JKGCM...
# 215              juan_du  [2tQVlXgA, x8gVaC1l, M5vrhWX3, 3W0mPmWi, xKAbW...
# 216      hiroaki_okamoto  [LGcWUHZe, 8mPqiOw9, FHbmL2jX, eENv2Wuh, U2IDa...
# 217             dan_wang  [Pxy7hkaf, WLncYKR0, rev1qrvb, qiadKgDB, 4j5kq...
# 218             jun_chen  [AUYRKdop, EcUVStC9, 7U2oA8Ei, 8aadbYEC, 1YTud...
# 219             bai_yang  [MiIxNg2Y, nnXl5kA9, qsAl4WGb, Mth7l53q, ZtC2S...
# 220     hiroshi_sakamoto  [vwt9Wd81, MLEuzS1T, xOEKHNxv, Ms4yXx88, VosVg...
#
#      author_num
# 0           249
# 1            57
# 2           112
# 3            28
# 4            27
# 5           379
# 6            22
# 7             5
# 8            24
# 9             5
# 10           23
# 11           36
# 12          436
# 13           25
# 14           10
# 15          232
# 16           21
# 17           11
# 18          123
# 19           27
# 20           30
# 21           19
# 22            7
# 23           27
# 24          290
# 25           22
# 26           92
# 27           16
# 28            9
# 29           17
# ..          ...
# 188         255
# 189          69
# 190          15
# 192         231
# 194           8
# 195          27
# 196           5
# 197          36
# 198          69
# 199         302
# 200         357
# 201          24
# 202           9
# 203         588
# 204         160
# 205         518
# 206         331
# 207          18
# 208          29
# 209          13
# 211          62
# 212         179
# 213          11
# 214         282
# 215          20
# 216           8
# 217          24
# 218         231
# 219          27
# 220          11
#
# [204 rows x 3 columns]

# %%
train_author_name_ids_ext = []
for author_name, author_ids in train_author_name_ids[['author_name', 'author_ids']].values:
     for aid in author_ids:
            train_author_name_ids_ext.append([author_name, aid])
            
train_author_name_ids_ext = pd.DataFrame(train_author_name_ids_ext, columns=['author_name', 'author_id'])
train_author_name_ids_ext.head()
# Out:
#   author_name author_id
# 0      li_guo  EShnTfSe
# 1      li_guo  sCKCrny5
# 2      li_guo  SY2FEqNj
# 3      li_guo  XXFI1LfP
# 4      li_guo  KZUHqEs8

# %%
# remove author that pub less than k

# %%
train_author_paper_ids = pd.read_pickle('./pkl/train_author_paper_ids.pkl')

# %%
train_author_paper_ids['paper_num'] = train_author_paper_ids['paper_ids'].apply(len)
train_author_paper_ids['paper_num'].describe()
# Out:
# count    22839.000000
# mean         8.997679
# std         37.176879
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          7.000000
# max       1646.000000
# Name: paper_num, dtype: float64

# %%
author_pub_more_than_k = train_author_paper_ids[train_author_paper_ids['paper_num'] > 0]['author_id'].unique()
print(len(author_pub_more_than_k), train_author_paper_ids['author_id'].nunique())
# Out:
# 22839 22839

# %%
print(len(train_author_name_ids_ext))
train_author_name_ids_ext = train_author_name_ids_ext[train_author_name_ids_ext['author_id'].isin(author_pub_more_than_k)]
print(len(train_author_name_ids_ext))
# Out:
# 22782
# 22782

# %%
train_author_paper_ids_ext = []
for author_id, paper_ids in train_author_paper_ids[['author_id', 'paper_ids']].values:
     for pid in paper_ids:
            train_author_paper_ids_ext.append([author_id, pid])
train_author_paper_ids_ext = pd.DataFrame(train_author_paper_ids_ext, columns=['author_id', 'paper_id'])

# %%
# train_pub_info = pd.read_pickle('./pkl/train_pub_info.pkl')[['paper_id', 'authors']]

# %%
# train_author_paper_ids_ext = train_author_paper_ids_ext.merge(train_pub_info, 'left', 'paper_id')

# %%
train_author_paper_ids_ext = train_author_paper_ids_ext.merge(train_author_name_ids_ext, 'left', 'author_id')

# %%
train_author_paper_ids_ext.head()
# Out:
#   author_id  paper_id author_name
# 0  EShnTfSe  P9a1gcvg      li_guo
# 1  sCKCrny5  Rg5fAeTd      li_guo
# 2  sCKCrny5  lJPsGNBE      li_guo
# 3  sCKCrny5  er5gTz90      li_guo
# 4  sCKCrny5  UG32p2zs      li_guo

# %%
train_author_paper_ids_ext = train_author_paper_ids_ext.dropna(subset=['author_name'])

# %%
# %%time
train_author_paper_ids_ext['author_org'] = train_author_paper_ids_ext.apply(lambda row: author_org_map[row['author_name']][row['paper_id']], axis=1)
# Out:
# CPU times: user 11.3 s, sys: 41.3 ms, total: 11.4 s
# Wall time: 11.4 s

# %%
train_author_paper_ids_ext['author_org'].nunique() / len(train_author_paper_ids_ext)
# Out:
# 0.36125013573409936

# %%
train_author_paper_ids_ext.head()
# Out:
#   author_id  paper_id author_name                                author_org
# 0  EShnTfSe  P9a1gcvg      li_guo  Institute of Pharmacology and Toxicology
# 1  sCKCrny5  Rg5fAeTd      li_guo         Dept. of Pharmaceutical Chemistry
# 2  sCKCrny5  lJPsGNBE      li_guo        Department of Chemical Engineering
# 3  sCKCrny5  er5gTz90      li_guo                  Sichuan Union University
# 4  sCKCrny5  UG32p2zs      li_guo             West China School of Pharmacy

# %%
train_author_name_ids_ext.head()
# Out:
#   author_name author_id
# 0      li_guo  EShnTfSe
# 1      li_guo  sCKCrny5
# 2      li_guo  SY2FEqNj
# 3      li_guo  XXFI1LfP
# 4      li_guo  KZUHqEs8

# %%
train_author_name_ids_ext2 = train_author_name_ids_ext.merge(train_author_name_ids[['author_name', 'author_ids']], 'left', 'author_name')

# %%
train_author_name_ids_ext2.head()
# Out:
#   author_name author_id                                         author_ids
# 0      li_guo  EShnTfSe  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...
# 1      li_guo  sCKCrny5  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...
# 2      li_guo  SY2FEqNj  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...
# 3      li_guo  XXFI1LfP  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...
# 4      li_guo  KZUHqEs8  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...

# %%
# sample 
n = 5
train_author_name_ids_ext2['author_ids_sample'] = train_author_name_ids_ext2['author_ids'].apply(lambda x: np.random.permutation(x)[:n])

# %%
train_author_name_ids_ext2['author_ids_sample'] = train_author_name_ids_ext2.apply(lambda row: {row['author_id']} | set(row['author_ids_sample']), axis=1)
train_author_name_ids_ext2.head()
# Out:
#   author_name author_id                                         author_ids  \
# 0      li_guo  EShnTfSe  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...
# 1      li_guo  sCKCrny5  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...
# 2      li_guo  SY2FEqNj  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...
# 3      li_guo  XXFI1LfP  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...
# 4      li_guo  KZUHqEs8  [EShnTfSe, sCKCrny5, SY2FEqNj, XXFI1LfP, KZUHq...
#
#                                    author_ids_sample
# 0  {8GjtUmBs, EShnTfSe, t1ruuB9N, xLLXKy6I, jTu2A...
# 1  {PAZF8zlm, eGjj8Ese, tkaLWFV8, 58iKrVpc, sCKCr...
# 2  {SY2FEqNj, fnrQVlgp, SQ2fucxi, fy0e5Ywx, yXftG...
# 3  {DwtOOnzZ, kbFi9XoZ, rGwozEzu, XXFI1LfP, 1puJW...
# 4  {EUjMRrjW, 7EBzXNd9, UAKj9Sgw, KZUHqEs8, qpezO...

# %%
train_author_ids_ext2_sample = []
for author_id, author_ids_sample in train_author_name_ids_ext2[['author_id', 'author_ids_sample']].values:
     for aid in author_ids_sample:
            train_author_ids_ext2_sample.append([author_id, aid])
            
train_author_ids_ext2_sample = pd.DataFrame(train_author_ids_ext2_sample, columns=['author_id', 'author_id_sample'])
train_author_ids_ext2_sample.head()
# Out:
#   author_id author_id_sample
# 0  EShnTfSe         8GjtUmBs
# 1  EShnTfSe         EShnTfSe
# 2  EShnTfSe         t1ruuB9N
# 3  EShnTfSe         xLLXKy6I
# 4  EShnTfSe         jTu2AZES

# %%
train_data = train_author_paper_ids_ext.merge(train_author_ids_ext2_sample, 'left', 'author_id')

# %%
train_data['label'] = (train_data['author_id'] == train_data['author_id_sample']).astype(int)

# %%
train_data.drop(columns=['author_id'], inplace=True)

# %%
train_data.columns = ['paper_id', 'author_name', 'author_org', 'author_id', 'label']

# %%
train_data['label'].value_counts()
# Out:
# 0    992394
# 1    202602
# Name: label, dtype: int64

# %%
train_data.head()
# Out:
#    paper_id author_name                                author_org author_id  \
# 0  P9a1gcvg      li_guo  Institute of Pharmacology and Toxicology  8GjtUmBs
# 1  P9a1gcvg      li_guo  Institute of Pharmacology and Toxicology  EShnTfSe
# 2  P9a1gcvg      li_guo  Institute of Pharmacology and Toxicology  t1ruuB9N
# 3  P9a1gcvg      li_guo  Institute of Pharmacology and Toxicology  xLLXKy6I
# 4  P9a1gcvg      li_guo  Institute of Pharmacology and Toxicology  jTu2AZES
#
#    label
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0

# %%
train_data.to_pickle('./pkl/train_data.pkl')
