# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] ='0'

# %%
import pandas as pd
import numpy as np
import gc
import time

# %%
out_dir = './out/'
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from catboost import CatBoostClassifier, Pool

# %%
train_data = pd.read_pickle('./pkl/train_data.pkl')
test_data = pd.read_pickle('./pkl/valid_data.pkl')

# %%
data = pd.concat([train_data, test_data]).reset_index(drop=True)

# %%
data.head()
# Out:
#   author_id author_name                                author_org  label  \
# 0  8GjtUmBs      li_guo  Institute of Pharmacology and Toxicology    0.0
# 1  EShnTfSe      li_guo  Institute of Pharmacology and Toxicology    1.0
# 2  t1ruuB9N      li_guo  Institute of Pharmacology and Toxicology    0.0
# 3  xLLXKy6I      li_guo  Institute of Pharmacology and Toxicology    0.0
# 4  jTu2AZES      li_guo  Institute of Pharmacology and Toxicology    0.0
#
#    paper_id
# 0  P9a1gcvg
# 1  P9a1gcvg
# 2  P9a1gcvg
# 3  P9a1gcvg
# 4  P9a1gcvg

# %%
print(train_data.shape)
print(test_data.shape)
print(data.shape)
# Out:
# (1194996, 5)
# (452786, 4)
# (1647782, 5)

# %%
##
time_feat_a = pd.read_pickle('./feat/time_feat_a.pkl')
rank_feat = pd.read_pickle('./feat/rank_feat3.pkl')

# %%
feats = [time_feat_a, rank_feat]

# %%
data = pd.concat([data] + feats, axis=1)

# %%
data.head()
# Out:
#   author_id author_name                                author_org  label  \
# 0  8GjtUmBs      li_guo  Institute of Pharmacology and Toxicology    0.0
# 1  EShnTfSe      li_guo  Institute of Pharmacology and Toxicology    1.0
# 2  t1ruuB9N      li_guo  Institute of Pharmacology and Toxicology    0.0
# 3  xLLXKy6I      li_guo  Institute of Pharmacology and Toxicology    0.0
# 4  jTu2AZES      li_guo  Institute of Pharmacology and Toxicology    0.0
#
#    paper_id  year_a  year_b_min  year_b_max  year_b_mean  year_b_std  \
# 0  P9a1gcvg    1996        2013        2013       2013.0         0.0
# 1  P9a1gcvg    1996           0           0          0.0         0.0
# 2  P9a1gcvg    1996        2011        2011       2011.0         0.0
# 3  P9a1gcvg    1996        2008        2008       2008.0         0.0
# 4  P9a1gcvg    1996        2011        2011       2011.0         0.0
#
#               ...              authors_sims_mm2_bert_rank_b  \
# 0             ...                                       5.0
# 1             ...                                       6.0
# 2             ...                                       4.0
# 3             ...                                       1.0
# 4             ...                                       3.0
#
#    orgs_sims_min_bert_rank_b  orgs_sims_max_bert_rank_b  \
# 0                        4.0                        4.0
# 1                        6.0                        6.0
# 2                        5.0                        5.0
# 3                        3.0                        3.0
# 4                        1.0                        1.0
#
#    orgs_sims_mean_bert_rank_b  orgs_sims_std_bert_rank_b  \
# 0                         4.0                        4.0
# 1                         6.0                        4.0
# 2                         5.0                        4.0
# 3                         3.0                        4.0
# 4                         1.0                        4.0
#
#    orgs_sims_mm2_bert_rank_b  orgs_sims_max2_bert_rank_b  \
# 0                        4.0                         4.0
# 1                        6.0                         6.0
# 2                        5.0                         5.0
# 3                        3.0                         3.0
# 4                        1.0                         1.0
#
#    orgs_sims_min2_bert_rank_b  orgs_sims_mean2_bert_rank_b  \
# 0                         4.0                          4.0
# 1                         6.0                          6.0
# 2                         5.0                          5.0
# 3                         3.0                          3.0
# 4                         1.0                          1.0
#
#    orgs_sims_std2_bert_rank_b
# 0                         3.5
# 1                         3.5
# 2                         3.5
# 3                         3.5
# 4                         3.5
#
# [5 rows x 168 columns]

# %%
drop_feat = ['author_id', 'author_name', 'author_org', 'paper_id', 'label']
used_feat = [c for c in data.columns if c not in drop_feat]
print(len(used_feat))
print(used_feat)
# Out:
# 95
# ['year_a', 'year_b_min', 'year_b_max', 'year_b_mean', 'year_b_std', 'year_b_mm2', 'year_b_min-year_a', 'year_b_max-year_a', 'year_b_mean-year_a', 'year_b_mm2-year_a', 'year_inside_range', 'paper_num_rank_a', 'author_org_in_orgs_b_times_rank_a', 'author_interset_num_rank_a', 'author_interset_num/paper_ids_len_rank_a', 'venue_a_in_venue_b_num_rank_a', 'keywords_interset_num_rank_a', 'venue_a_in_venue_b_num/paper_ids_len_rank_a', 'keywords_interset_num/paper_ids_len_rank_a', 'abstract_sims_min_bert_rank_a', 'abstract_sims_max_bert_rank_a', 'abstract_sims_mean_bert_rank_a', 'abstract_sims_std_bert_rank_a', 'abstract_sims_mm2_bert_rank_a', 'keywords_sims_min_bert_rank_a', 'keywords_sims_max_bert_rank_a', 'keywords_sims_mean_bert_rank_a', 'keywords_sims_std_bert_rank_a', 'keywords_sims_mm2_bert_rank_a', 'title_sims_min_bert_rank_a', 'title_sims_max_bert_rank_a', 'title_sims_mean_bert_rank_a', 'title_sims_std_bert_rank_a', 'title_sims_mm2_bert_rank_a', 'venue_sims_min_bert_rank_a', 'venue_sims_max_bert_rank_a', 'venue_sims_mean_bert_rank_a', 'venue_sims_std_bert_rank_a', 'venue_sims_mm2_bert_rank_a', 'authors_sims_min_bert_rank_a', 'authors_sims_max_bert_rank_a', 'authors_sims_mean_bert_rank_a', 'authors_sims_std_bert_rank_a', 'authors_sims_mm2_bert_rank_a', 'orgs_sims_min_bert_rank_a', 'orgs_sims_max_bert_rank_a', 'orgs_sims_mean_bert_rank_a', 'orgs_sims_std_bert_rank_a', 'orgs_sims_mm2_bert_rank_a', 'orgs_sims_max2_bert_rank_a', 'orgs_sims_min2_bert_rank_a', 'orgs_sims_mean2_bert_rank_a', 'orgs_sims_std2_bert_rank_a', 'paper_num_rank_b', 'author_org_in_orgs_b_times_rank_b', 'author_interset_num_rank_b', 'author_interset_num/paper_ids_len_rank_b', 'venue_a_in_venue_b_num_rank_b', 'keywords_interset_num_rank_b', 'venue_a_in_venue_b_num/paper_ids_len_rank_b', 'keywords_interset_num/paper_ids_len_rank_b', 'abstract_sims_min_bert_rank_b', 'abstract_sims_max_bert_rank_b', 'abstract_sims_mean_bert_rank_b', 'abstract_sims_std_bert_rank_b', 'abstract_sims_mm2_bert_rank_b', 'keywords_sims_min_bert_rank_b', 'keywords_sims_max_bert_rank_b', 'keywords_sims_mean_bert_rank_b', 'keywords_sims_std_bert_rank_b', 'keywords_sims_mm2_bert_rank_b', 'title_sims_min_bert_rank_b', 'title_sims_max_bert_rank_b', 'title_sims_mean_bert_rank_b', 'title_sims_std_bert_rank_b', 'title_sims_mm2_bert_rank_b', 'venue_sims_min_bert_rank_b', 'venue_sims_max_bert_rank_b', 'venue_sims_mean_bert_rank_b', 'venue_sims_std_bert_rank_b', 'venue_sims_mm2_bert_rank_b', 'authors_sims_min_bert_rank_b', 'authors_sims_max_bert_rank_b', 'authors_sims_mean_bert_rank_b', 'authors_sims_std_bert_rank_b', 'authors_sims_mm2_bert_rank_b', 'orgs_sims_min_bert_rank_b', 'orgs_sims_max_bert_rank_b', 'orgs_sims_mean_bert_rank_b', 'orgs_sims_std_bert_rank_b', 'orgs_sims_mm2_bert_rank_b', 'orgs_sims_max2_bert_rank_b', 'orgs_sims_min2_bert_rank_b', 'orgs_sims_mean2_bert_rank_b', 'orgs_sims_std2_bert_rank_b']

# %%
train = data[:len(train_data)]
test = data[len(train_data):]

# %%
test_x = test[used_feat]

# %%
# cv split according to author names
train_author_name = train['author_name'].unique()
print(len(train_author_name))
# Out:
# 204

# %%
def gen_dict(df, label):
    df = df[['paper_id', 'author_name', 'author_id', label]]
    res = df.groupby(['paper_id', 'author_name'])[label].apply(np.argmax).reset_index()
    res.columns = ['paper_id', 'author_name', 'index']
    idx_name = df[['author_id']].reset_index()
    res = res.merge(idx_name, 'left', 'index')
    from collections import defaultdict
    res_dict = defaultdict(list)
    for pid, aid in res[['paper_id', 'author_id']].values:
        res_dict[aid].append(pid)
    return res_dict

# %%
def f1_score(pred_dict, true_dict):
    total_unassigned_paper = np.sum([len(l) for l in true_dict.values()])
    print('total_unassigned_paper: ', total_unassigned_paper)
    print('true author num: ', len(true_dict))
    author_weight = dict((k, len(v) / total_unassigned_paper) for k, v in true_dict.items())
    author_precision = {}
    author_recall = {}
    for author in author_weight.keys():
        # total pred, total belong, correct pred
        total_belong = len(true_dict[author])
        total_pred = (len(pred_dict[author]) if author in pred_dict else 0)
        correct_pred = len(set(true_dict[author]) & (set(pred_dict[author]) if author in pred_dict else set()))
        author_precision[author] = (correct_pred/total_pred) if total_pred > 0 else 0
        author_recall[author] = correct_pred / total_belong
        
    weighted_precision = 0
    weighted_recall = 0
    for author, weight in author_weight.items():
        weighted_precision += weight * author_precision[author]
        weighted_recall += weight * author_recall[author]
    weighted_f1 = 2 * weighted_precision * weighted_recall / (weighted_precision + weighted_recall)
    print('weighted_precision: %f, weighted_recall: %f, weighted_f1: %f' %(weighted_precision, weighted_recall, weighted_f1))
    return weighted_precision, weighted_recall, weighted_f1

# %%
from sklearn.model_selection import KFold
preds = np.zeros((test.shape[0], 2))
scores = []
f1_scores = []
has_saved = False
imp = pd.DataFrame()
imp['feat'] = used_feat

kfold = KFold(n_splits=5, shuffle=True, random_state=42)
for index, (tr_idx, va_idx) in enumerate(kfold.split(train_author_name)):
    print('*' * 30)
    trn_aname, val_aname = train_author_name[tr_idx], train_author_name[va_idx]
    trn_dat = train[train['author_name'].isin(trn_aname)]
    val_dat = train[train['author_name'].isin(val_aname)]
    X_train, y_train, X_valid, y_valid = trn_dat[used_feat], trn_dat['label'], val_dat[used_feat], val_dat['label']
    cate_features = []
    train_pool = Pool(X_train, y_train, cat_features=cate_features)
    eval_pool = Pool(X_valid, y_valid,cat_features=cate_features)
    if not has_saved: 
        cbt_model = CatBoostClassifier(iterations=10000,
                           learning_rate=0.1,
                           eval_metric='AUC',
                           use_best_model=True,
                           random_seed=42,
                           logging_level='Verbose',
                           task_type='GPU',
                           devices='0',
#                            gpu_ram_part=0.5,
                           early_stopping_rounds=300,
                           loss_function='Logloss',
#                            depth=12,
                           )
        cbt_model.fit(train_pool, eval_set=eval_pool, verbose=100)
#         with open('./models/fold%d_cbt_v1.mdl' % index, 'wb') as file:
#             pickle.dump(cbt_model, file)
#     else:
#         with open('./models/fold%d_cbt_v1.mdl' % index, 'rb') as file:
#             cbt_model = pickle.load(file)
    
    imp['score%d' % (index+1)] = cbt_model.feature_importances_
    
    val_dat['pred'] = cbt_model.predict_proba(X_valid)[:, 1]
    val_pred_dict = gen_dict(val_dat, 'pred')
    val_true_dict = gen_dict(val_dat, 'label')
    precision, recall, f1 = f1_score(val_pred_dict, val_true_dict)
    f1_scores.append(f1)
    
    score = cbt_model.best_score_['validation']['AUC']
    scores.append(score)
    print('fold %d round %d : auc: %.6f | mean auc %.6f | F1: %.6f | mean F1: %.6f' % (index+1, cbt_model.best_iteration_, score,np.mean(scores), f1, np.mean(f1_scores))) 
    preds += cbt_model.predict_proba(test_x)  
#     break
    del cbt_model, train_pool, eval_pool
    del X_train, y_train, X_valid, y_valid
    import gc
    gc.collect()
    
#     mdls.append(cbt_model)
# Out:
# ******************************
# Warning: less than 75% gpu memory available for training. Free: 4388.5625 Total: 4388.5625
# 0:	learn: 0.9975497	test: 0.9971379	best: 0.9971379 (0)	total: 15.8ms	remaining: 2m 38s
# 100:	learn: 0.9997494	test: 0.9996755	best: 0.9996755 (100)	total: 1.31s	remaining: 2m 8s
# 200:	learn: 0.9998242	test: 0.9997479	best: 0.9997479 (200)	total: 2.56s	remaining: 2m 5s
# 300:	learn: 0.9998572	test: 0.9997733	best: 0.9997734 (299)	total: 3.83s	remaining: 2m 3s
# 400:	learn: 0.9998775	test: 0.9997894	best: 0.9997895 (399)	total: 5.11s	remaining: 2m 2s
# 500:	learn: 0.9998966	test: 0.9997950	best: 0.9997954 (489)	total: 6.39s	remaining: 2m 1s
# 600:	learn: 0.9999099	test: 0.9998027	best: 0.9998028 (595)	total: 7.71s	remaining: 2m
# 700:	learn: 0.9999231	test: 0.9998082	best: 0.9998084 (695)	total: 8.99s	remaining: 1m 59s
# 800:	learn: 0.9999328	test: 0.9998132	best: 0.9998132 (800)	total: 10.3s	remaining: 1m 58s
# 900:	learn: 0.9999403	test: 0.9998142	best: 0.9998147 (874)	total: 11.6s	remaining: 1m 56s
# 1000:	learn: 0.9999473	test: 0.9998164	best: 0.9998177 (989)	total: 12.8s	remaining: 1m 55s
# 1100:	learn: 0.9999529	test: 0.9998193	best: 0.9998197 (1098)	total: 14.1s	remaining: 1m 54s
# 1200:	learn: 0.9999587	test: 0.9998221	best: 0.9998222 (1198)	total: 15.4s	remaining: 1m 52s
# 1300:	learn: 0.9999638	test: 0.9998223	best: 0.9998235 (1254)	total: 16.7s	remaining: 1m 51s
# 1400:	learn: 0.9999681	test: 0.9998237	best: 0.9998238 (1389)	total: 18s	remaining: 1m 50s
# 1500:	learn: 0.9999716	test: 0.9998228	best: 0.9998238 (1389)	total: 19.2s	remaining: 1m 48s
# 1600:	learn: 0.9999748	test: 0.9998226	best: 0.9998238 (1389)	total: 20.5s	remaining: 1m 47s
# 1700:	learn: 0.9999783	test: 0.9998230	best: 0.9998247 (1649)	total: 21.8s	remaining: 1m 46s
# 1800:	learn: 0.9999810	test: 0.9998214	best: 0.9998247 (1649)	total: 23.2s	remaining: 1m 45s
# 1900:	learn: 0.9999835	test: 0.9998207	best: 0.9998247 (1649)	total: 24.5s	remaining: 1m 44s
# bestTest = 0.9998247027
# bestIteration = 1649
# Shrink model to first 1650 iterations.
# total_unassigned_paper:  42757
# true author num:  4867
# weighted_precision: 0.994035, weighted_recall: 0.993779, weighted_f1: 0.993907
# fold 1 round 1649 : auc: 0.999825 | mean auc 0.999825 | F1: 0.993907 | mean F1: 0.993907
# ******************************
# Warning: less than 75% gpu memory available for training. Free: 4388.5625 Total: 4388.5625
# 0:	learn: 0.9972583	test: 0.9969720	best: 0.9969720 (0)	total: 46.3ms	remaining: 7m 42s
# 100:	learn: 0.9997396	test: 0.9996647	best: 0.9996647 (100)	total: 2.63s	remaining: 4m 18s
# 200:	learn: 0.9998118	test: 0.9997188	best: 0.9997193 (197)	total: 5.29s	remaining: 4m 18s
# 300:	learn: 0.9998518	test: 0.9997449	best: 0.9997452 (298)	total: 7.98s	remaining: 4m 17s
# 400:	learn: 0.9998756	test: 0.9997635	best: 0.9997640 (399)	total: 10.7s	remaining: 4m 17s
# 500:	learn: 0.9998925	test: 0.9997688	best: 0.9997688 (500)	total: 13.5s	remaining: 4m 16s
# 600:	learn: 0.9999071	test: 0.9997710	best: 0.9997720 (557)	total: 16.1s	remaining: 4m 12s
# 700:	learn: 0.9999195	test: 0.9997789	best: 0.9997789 (700)	total: 18.8s	remaining: 4m 9s
# 800:	learn: 0.9999287	test: 0.9997822	best: 0.9997822 (796)	total: 21.4s	remaining: 4m 5s
# 900:	learn: 0.9999379	test: 0.9997869	best: 0.9997870 (895)	total: 24s	remaining: 4m 2s
# 1000:	learn: 0.9999461	test: 0.9997880	best: 0.9997884 (988)	total: 26.8s	remaining: 4m 1s
# 1100:	learn: 0.9999518	test: 0.9997918	best: 0.9997920 (1096)	total: 29.4s	remaining: 3m 57s
# 1200:	learn: 0.9999573	test: 0.9997933	best: 0.9997943 (1153)	total: 32s	remaining: 3m 54s
# 1300:	learn: 0.9999630	test: 0.9997929	best: 0.9997943 (1153)	total: 34.8s	remaining: 3m 52s
# 1400:	learn: 0.9999673	test: 0.9997923	best: 0.9997943 (1153)	total: 37.3s	remaining: 3m 48s
# bestTest = 0.9997943044
# bestIteration = 1153
# Shrink model to first 1154 iterations.
# total_unassigned_paper:  36561
# true author num:  4496
# weighted_precision: 0.993350, weighted_recall: 0.993107, weighted_f1: 0.993229
# fold 2 round 1153 : auc: 0.999794 | mean auc 0.999810 | F1: 0.993229 | mean F1: 0.993568
# ******************************
# Warning: less than 75% gpu memory available for training. Free: 4388.5625 Total: 4388.5625
# 0:	learn: 0.9974340	test: 0.9970190	best: 0.9970190 (0)	total: 17ms	remaining: 2m 49s
# 100:	learn: 0.9997501	test: 0.9996758	best: 0.9996758 (100)	total: 2.5s	remaining: 4m 4s
# 200:	learn: 0.9998254	test: 0.9997292	best: 0.9997292 (200)	total: 5.11s	remaining: 4m 9s
# 300:	learn: 0.9998624	test: 0.9997545	best: 0.9997545 (300)	total: 7.62s	remaining: 4m 5s
# 400:	learn: 0.9998850	test: 0.9997683	best: 0.9997689 (396)	total: 10.1s	remaining: 4m 1s
# 500:	learn: 0.9999032	test: 0.9997736	best: 0.9997737 (497)	total: 12.7s	remaining: 4m 1s
# 600:	learn: 0.9999161	test: 0.9997758	best: 0.9997759 (597)	total: 15.3s	remaining: 3m 59s
# 700:	learn: 0.9999282	test: 0.9997799	best: 0.9997799 (683)	total: 17.9s	remaining: 3m 58s
# 800:	learn: 0.9999378	test: 0.9997867	best: 0.9997867 (800)	total: 20.6s	remaining: 3m 56s
# 900:	learn: 0.9999455	test: 0.9997877	best: 0.9997891 (884)	total: 23.1s	remaining: 3m 53s
# 1000:	learn: 0.9999517	test: 0.9997847	best: 0.9997891 (884)	total: 25.7s	remaining: 3m 51s
# 1100:	learn: 0.9999573	test: 0.9997888	best: 0.9997891 (884)	total: 28.4s	remaining: 3m 49s
# 1200:	learn: 0.9999627	test: 0.9997897	best: 0.9997905 (1195)	total: 31s	remaining: 3m 46s
# 1300:	learn: 0.9999671	test: 0.9997894	best: 0.9997905 (1195)	total: 33.6s	remaining: 3m 44s
# 1400:	learn: 0.9999710	test: 0.9997894	best: 0.9997905 (1195)	total: 36.1s	remaining: 3m 41s
# 1500:	learn: 0.9999746	test: 0.9997917	best: 0.9997923 (1453)	total: 38.5s	remaining: 3m 38s
# 1600:	learn: 0.9999779	test: 0.9997886	best: 0.9997923 (1453)	total: 41.2s	remaining: 3m 36s
# 1700:	learn: 0.9999806	test: 0.9997883	best: 0.9997923 (1453)	total: 43.9s	remaining: 3m 34s
# bestTest = 0.9997922778
# bestIteration = 1453
# Shrink model to first 1454 iterations.
# total_unassigned_paper:  42971
# true author num:  4468
# weighted_precision: 0.994087, weighted_recall: 0.993647, weighted_f1: 0.993867
# fold 3 round 1453 : auc: 0.999792 | mean auc 0.999804 | F1: 0.993867 | mean F1: 0.993668
# ******************************
# 0:	learn: 0.9974858	test: 0.9985495	best: 0.9985495 (0)	total: 16.7ms	remaining: 2m 46s
# 100:	learn: 0.9997184	test: 0.9998342	best: 0.9998342 (100)	total: 1.32s	remaining: 2m 9s
# 200:	learn: 0.9997941	test: 0.9998685	best: 0.9998685 (199)	total: 2.62s	remaining: 2m 7s
# 300:	learn: 0.9998313	test: 0.9998823	best: 0.9998823 (299)	total: 3.88s	remaining: 2m 5s
# 400:	learn: 0.9998623	test: 0.9998891	best: 0.9998891 (392)	total: 5.14s	remaining: 2m 3s
# 500:	learn: 0.9998828	test: 0.9998931	best: 0.9998939 (482)	total: 6.42s	remaining: 2m 1s
# 600:	learn: 0.9998984	test: 0.9998953	best: 0.9998955 (581)	total: 7.71s	remaining: 2m
# 700:	learn: 0.9999109	test: 0.9998994	best: 0.9998997 (695)	total: 9.02s	remaining: 1m 59s
# 800:	learn: 0.9999220	test: 0.9999006	best: 0.9999010 (779)	total: 10.3s	remaining: 1m 58s
# 900:	learn: 0.9999312	test: 0.9999031	best: 0.9999034 (897)	total: 11.6s	remaining: 1m 57s
# 1000:	learn: 0.9999390	test: 0.9999030	best: 0.9999034 (897)	total: 12.9s	remaining: 1m 55s
# 1100:	learn: 0.9999466	test: 0.9999055	best: 0.9999055 (1099)	total: 14.1s	remaining: 1m 54s
# 1200:	learn: 0.9999529	test: 0.9999067	best: 0.9999068 (1195)	total: 15.4s	remaining: 1m 52s
# 1300:	learn: 0.9999585	test: 0.9999071	best: 0.9999074 (1257)	total: 16.7s	remaining: 1m 51s
# 1400:	learn: 0.9999635	test: 0.9999079	best: 0.9999081 (1361)	total: 18s	remaining: 1m 50s
# 1500:	learn: 0.9999673	test: 0.9999080	best: 0.9999081 (1361)	total: 19.4s	remaining: 1m 49s
# 1600:	learn: 0.9999709	test: 0.9999073	best: 0.9999081 (1361)	total: 20.7s	remaining: 1m 48s
# bestTest = 0.9999081492
# bestIteration = 1361
# Shrink model to first 1362 iterations.
# total_unassigned_paper:  44391
# true author num:  4719
# weighted_precision: 0.995167, weighted_recall: 0.995044, weighted_f1: 0.995106
# fold 4 round 1361 : auc: 0.999908 | mean auc 0.999830 | F1: 0.995106 | mean F1: 0.994027
# ******************************
# 0:	learn: 0.9977620	test: 0.9972097	best: 0.9972097 (0)	total: 17ms	remaining: 2m 49s
# 100:	learn: 0.9997423	test: 0.9996644	best: 0.9996644 (100)	total: 1.42s	remaining: 2m 19s
# 200:	learn: 0.9998112	test: 0.9997213	best: 0.9997213 (200)	total: 2.82s	remaining: 2m 17s
# 300:	learn: 0.9998519	test: 0.9997436	best: 0.9997436 (300)	total: 4.24s	remaining: 2m 16s
# 400:	learn: 0.9998763	test: 0.9997526	best: 0.9997527 (399)	total: 5.71s	remaining: 2m 16s
# 500:	learn: 0.9998931	test: 0.9997582	best: 0.9997586 (491)	total: 7.11s	remaining: 2m 14s
# 600:	learn: 0.9999086	test: 0.9997628	best: 0.9997630 (595)	total: 8.52s	remaining: 2m 13s
# 700:	learn: 0.9999208	test: 0.9997649	best: 0.9997666 (630)	total: 9.92s	remaining: 2m 11s
# 800:	learn: 0.9999307	test: 0.9997659	best: 0.9997666 (630)	total: 11.3s	remaining: 2m 9s
# 900:	learn: 0.9999394	test: 0.9997656	best: 0.9997668 (882)	total: 12.8s	remaining: 2m 8s
# 1000:	learn: 0.9999467	test: 0.9997666	best: 0.9997668 (882)	total: 14.2s	remaining: 2m 7s
# 1100:	learn: 0.9999532	test: 0.9997687	best: 0.9997687 (1099)	total: 15.6s	remaining: 2m 5s
# 1200:	learn: 0.9999597	test: 0.9997683	best: 0.9997691 (1147)	total: 17s	remaining: 2m 4s
# 1300:	learn: 0.9999647	test: 0.9997692	best: 0.9997693 (1298)	total: 18.4s	remaining: 2m 3s
# 1400:	learn: 0.9999691	test: 0.9997697	best: 0.9997705 (1389)	total: 19.9s	remaining: 2m 1s
# 1500:	learn: 0.9999728	test: 0.9997672	best: 0.9997705 (1389)	total: 21.3s	remaining: 2m
# 1600:	learn: 0.9999760	test: 0.9997669	best: 0.9997705 (1389)	total: 22.7s	remaining: 1m 59s
# bestTest = 0.9997704625
# bestIteration = 1389
# Shrink model to first 1390 iterations.
# total_unassigned_paper:  35840
# true author num:  4214
# weighted_precision: 0.991886, weighted_recall: 0.991406, weighted_f1: 0.991646
# fold 5 round 1389 : auc: 0.999770 | mean auc 0.999818 | F1: 0.991646 | mean F1: 0.993551

# %%
imp.sort_values(by='score1', ascending=False)
# Out:
#                                            feat    score1    score2    score3  \
# 55                   author_interset_num_rank_b  8.298452  9.578436  7.598800
# 2                                    year_b_max  5.735328  6.535335  3.740404
# 91                   orgs_sims_max2_bert_rank_b  5.313472  5.694128  7.393179
# 13                   author_interset_num_rank_a  4.948066  4.680774  5.389117
# 4                                    year_b_std  3.532221  3.057120  3.247804
# 49                   orgs_sims_max2_bert_rank_a  3.236305  4.152073  5.122202
# 11                             paper_num_rank_a  2.297650  2.131351  2.037330
# 3                                   year_b_mean  2.252438  1.168923  2.083037
# 52                   orgs_sims_std2_bert_rank_a  2.173362  2.504588  1.786622
# 57                venue_a_in_venue_b_num_rank_b  2.056701  3.294738  1.887856
# 9                             year_b_mm2-year_a  2.008491  2.512041  2.005812
# 56     author_interset_num/paper_ids_len_rank_b  2.004028  1.760037  2.080413
# 53                             paper_num_rank_b  2.000704  1.781295  2.089642
# 72                   title_sims_max_bert_rank_b  1.969042  1.576145  1.828183
# 5                                    year_b_mm2  1.968963  1.787924  2.457097
# 59  venue_a_in_venue_b_num/paper_ids_len_rank_b  1.839003  1.257734  0.877650
# 12            author_org_in_orgs_b_times_rank_a  1.735343  1.402116  1.317598
# 14     author_interset_num/paper_ids_len_rank_a  1.691743  1.515626  1.528875
# 10                            year_inside_range  1.624007  0.786667  1.251221
# 8                            year_b_mean-year_a  1.588200  0.692718  1.507300
# 0                                        year_a  1.541591  2.442837  1.538997
# 7                             year_b_max-year_a  1.519968  2.755024  2.632201
# 51                  orgs_sims_mean2_bert_rank_a  1.450139  1.120694  0.931383
# 82                 authors_sims_max_bert_rank_b  1.322112  1.558610  1.226965
# 54            author_org_in_orgs_b_times_rank_b  1.175386  1.311069  2.164446
# 6                             year_b_min-year_a  1.151827  1.009140  0.958247
# 93                  orgs_sims_mean2_bert_rank_b  1.107941  0.489296  1.025109
# 44                    orgs_sims_min_bert_rank_a  1.081552  0.751255  0.696623
# 77                   venue_sims_max_bert_rank_b  0.889462  1.069687  0.991642
# 94                   orgs_sims_std2_bert_rank_b  0.866779  0.980031  0.952244
# ..                                          ...       ...       ...       ...
# 39                 authors_sims_min_bert_rank_a  0.410576  0.251978  0.466578
# 89                    orgs_sims_std_bert_rank_b  0.405391  0.327544  0.219746
# 17  venue_a_in_venue_b_num/paper_ids_len_rank_a  0.393324  0.632492  0.800952
# 47                    orgs_sims_std_bert_rank_a  0.392175  0.344238  0.508873
# 23                abstract_sims_mm2_bert_rank_a  0.379302  0.169454  0.346927
# 76                   venue_sims_min_bert_rank_b  0.379167  0.191031  0.245128
# 80                   venue_sims_mm2_bert_rank_b  0.376931  0.201727  0.384620
# 46                   orgs_sims_mean_bert_rank_a  0.369830  0.114240  0.230646
# 68               keywords_sims_mean_bert_rank_b  0.361449  0.357742  0.192362
# 61                abstract_sims_min_bert_rank_b  0.349830  0.327280  0.239938
# 42                 authors_sims_std_bert_rank_a  0.345005  0.213104  0.484045
# 37                   venue_sims_std_bert_rank_a  0.335925  0.280561  0.219818
# 63               abstract_sims_mean_bert_rank_b  0.333190  0.221689  0.307498
# 69                keywords_sims_std_bert_rank_b  0.332738  0.326019  0.476710
# 19                abstract_sims_min_bert_rank_a  0.318525  0.407954  0.421188
# 38                   venue_sims_mm2_bert_rank_a  0.316765  0.146759  0.191536
# 81                 authors_sims_min_bert_rank_b  0.306232  0.400674  0.360392
# 84                 authors_sims_std_bert_rank_b  0.303092  0.210011  0.217949
# 79                   venue_sims_std_bert_rank_b  0.302069  0.303074  0.416861
# 41                authors_sims_mean_bert_rank_a  0.300849  0.327235  0.211685
# 71                   title_sims_min_bert_rank_b  0.300268  0.244979  0.382181
# 26               keywords_sims_mean_bert_rank_a  0.279161  0.189983  0.100759
# 43                 authors_sims_mm2_bert_rank_a  0.270357  0.253769  0.341063
# 85                 authors_sims_mm2_bert_rank_b  0.247467  0.155342  0.281182
# 28                keywords_sims_mm2_bert_rank_a  0.233275  0.211766  0.154922
# 70                keywords_sims_mm2_bert_rank_b  0.224910  0.228418  0.262136
# 90                    orgs_sims_mm2_bert_rank_b  0.224068  0.138086  0.219107
# 48                    orgs_sims_mm2_bert_rank_a  0.211761  0.291360  0.194420
# 65                abstract_sims_mm2_bert_rank_b  0.201753  0.201010  0.290671
# 36                  venue_sims_mean_bert_rank_a  0.164030  0.207942  0.266810
#
#       score4    score5
# 55  7.475774  8.116196
# 2   5.142827  8.352572
# 91  7.184583  7.615661
# 13  5.553717  5.218932
# 4   3.318082  3.121897
# 49  3.326928  3.131560
# 11  2.180784  2.117218
# 3   4.591285  1.958823
# 52  2.619718  2.884649
# 57  3.237639  1.778620
# 9   0.340251  1.566271
# 56  1.738537  1.345648
# 53  2.097227  2.281512
# 72  1.726377  1.657107
# 5   1.011037  0.838681
# 59  1.444203  1.700464
# 12  1.164456  1.336619
# 14  1.187903  1.584299
# 10  0.779662  0.813357
# 8   1.081650  0.781860
# 0   1.454740  1.818557
# 7   3.376249  1.921294
# 51  0.924929  0.579085
# 82  1.473427  1.604767
# 54  1.160218  1.275777
# 6   1.096359  1.348554
# 93  0.628833  0.429666
# 44  0.914205  0.529106
# 77  0.916391  1.006488
# 94  1.515145  1.104695
# ..       ...       ...
# 39  0.328818  0.430818
# 89  0.381034  0.363560
# 17  0.348476  0.440102
# 47  0.466276  0.330494
# 23  0.363078  0.377655
# 76  0.205836  0.281396
# 80  0.357203  0.518069
# 46  0.412384  0.277407
# 68  0.281239  0.261446
# 61  0.237655  0.206550
# 42  0.291294  0.559067
# 37  0.193559  0.355494
# 63  0.184629  0.217488
# 69  0.398757  0.332403
# 19  0.154015  0.323406
# 38  0.320332  0.433849
# 81  0.519989  0.255747
# 84  0.438402  0.369037
# 79  0.334152  0.410621
# 41  0.332910  0.179289
# 71  0.382663  0.348616
# 26  0.218952  0.205560
# 43  0.309190  0.204094
# 85  0.194120  0.193588
# 28  0.227651  0.134563
# 70  0.230497  0.149155
# 90  0.294393  0.212926
# 48  0.113114  0.170742
# 65  0.235395  0.279009
# 36  0.165573  0.198246
#
# [95 rows x 6 columns]

# %%
test_data['pred'] = preds[:, 1]

# %%
test_data.head()
# Out:
#    paper_id author_name                         author_org author_id      pred
# 0  F3Mha4HG     lei_shi  State Key Laboratory of Catalysis  0gL4hj4n  0.041708
# 1  F3Mha4HG     lei_shi  State Key Laboratory of Catalysis  0jknXeWe  0.058157
# 2  F3Mha4HG     lei_shi  State Key Laboratory of Catalysis  1vE3Drg0  0.457224
# 3  F3Mha4HG     lei_shi  State Key Laboratory of Catalysis  2IVNIGb6  0.456184
# 4  F3Mha4HG     lei_shi  State Key Laboratory of Catalysis  5QgbLXhl  0.434320

# %%
result_dict = gen_dict(test_data, 'pred')

# %%
len(result_dict)
# Out:
# 1291

# %%
import json
import time
localtime = time.localtime(time.time())
save_path = './out/result_%02d%02d%02d%02d.json' % (localtime[1], localtime[2], localtime[3], localtime[4])
with open(save_path, 'w') as file:
    file.write(json.dumps(result_dict))
