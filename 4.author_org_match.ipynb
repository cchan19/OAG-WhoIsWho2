# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import os
import sys

# %%
import pickle

# %%
##
whole_pub_info = pd.read_pickle('./pkl/whole_pub_info.pkl')
whole_author_name_paper_ids = pd.read_pickle('./pkl/whole_author_name_paper_ids.pkl')
## 
train_pub_info = pd.read_pickle('./pkl/train_pub_info.pkl')
train_author_name_ids = pd.read_pickle('./pkl/train_author_name_ids.pkl')
train_author_paper_ids = pd.read_pickle('./pkl/train_author_paper_ids.pkl')
##
valid_pub_info = pd.read_pickle('./pkl/valid_pub_info.pkl')
valid_data = pd.read_pickle('./pkl/valid_data.pkl')

# %%
pub_info = pd.concat([whole_pub_info, train_pub_info, valid_pub_info])
print(pub_info.shape)
pub_info = pub_info.drop_duplicates(subset='paper_id', keep='first')
print(pub_info.shape)
# Out:
# (474711, 7)
# (271111, 7)

# %%
pub_info.head(2)
# Out:
#                                             abstract  \
# 0  Extremely long states of bound solitons consis...
# 1                                                NaN
#
#                                              authors  \
# 0  [{'name': 'Ya Liu', 'org': 'Sch. of Electron. ...
# 1         [{'name': 'Hao He'}, {'name': 'Jun Yang'}]
#
#                                             keywords  paper_id  \
# 0  [carbon nanotubes, fibre lasers, laser cavity ...  0009qJgC
# 1  [different part, data graph, variety ofstructu...  000BMUBY
#
#                                                title  \
# 0  Generating ultra-long bound soliton sequences ...
# 1  Multiresolution Indexing of XML for Frequent Q...
#
#                        venue  year
# 0  Lasers and Electro-Optics  2014
# 1                       icde  2004

# %%
pub_info = pub_info.set_index('paper_id')
pub_info.head(2)
# Out:
#                                                    abstract  \
# paper_id
# 0009qJgC  Extremely long states of bound solitons consis...
# 000BMUBY                                                NaN
#
#                                                     authors  \
# paper_id
# 0009qJgC  [{'name': 'Ya Liu', 'org': 'Sch. of Electron. ...
# 000BMUBY         [{'name': 'Hao He'}, {'name': 'Jun Yang'}]
#
#                                                    keywords  \
# paper_id
# 0009qJgC  [carbon nanotubes, fibre lasers, laser cavity ...
# 000BMUBY  [different part, data graph, variety ofstructu...
#
#                                                       title  \
# paper_id
# 0009qJgC  Generating ultra-long bound soliton sequences ...
# 000BMUBY  Multiresolution Indexing of XML for Frequent Q...
#
#                               venue  year
# paper_id
# 0009qJgC  Lasers and Electro-Optics  2014
# 000BMUBY                       icde  2004

# %%
pub_info.loc['0009qJgC', 'authors']
# Out:
# [OrderedDict([('name', 'Ya Liu'),
#               ('org',
#                'Sch. of Electron. & Inf. Eng., Beihang Univ., Beijing, China|c|')]),
#  OrderedDict([('name', 'Xin Zhao'), ('org', '')]),
#  OrderedDict([('name', 'Jiansheng Liu'), ('org', '')]),
#  OrderedDict([('name', 'Guoqing Hu'), ('org', '')])]

# %%
with open('./pkl/author_name_map.pkl', 'rb') as file:
    author_name_map = pickle.load(file)

# %%
whole_author_name_paper_ids.head(2)
# Out:
#   author_id    author_name                                          paper_ids
# 0  004mBKh6  changsheng_li  [lRl7m2tU, 1vUnZLES, 5IbEOTRh, dVAKsHla, TY0MY...
# 1  008b5hIc   yuanyuan_liu                                         [nPuf0kYs]

# %%
train_author_paper_ids.head(2)
# Out:
#   author_id                                          paper_ids
# 0  EShnTfSe                                         [P9a1gcvg]
# 1  sCKCrny5  [Rg5fAeTd, lJPsGNBE, er5gTz90, UG32p2zs, FTweB...

# %%
valid_data.head(2)
# Out:
#    paper_id author_name                         author_org author_id
# 0  F3Mha4HG     lei_shi  State Key Laboratory of Catalysis  0gL4hj4n
# 1  F3Mha4HG     lei_shi  State Key Laboratory of Catalysis  0jknXeWe

# %%
# dict: {author_name:{paper_id:org}}

# %%
train_author_name_ids = pd.read_pickle('./pkl/train_author_name_ids.pkl')

# %%
train_author_name_ids_ext = []
for author_name, author_ids in train_author_name_ids[['author_name', 'author_ids']].values:
     for aid in author_ids:
            train_author_name_ids_ext.append([author_name, aid])
            
train_author_name_ids_ext = pd.DataFrame(train_author_name_ids_ext, columns=['author_name', 'author_id'])
train_author_name_ids_ext.head()
# Out:
#   author_name author_id
# 0      li_guo  EShnTfSe
# 1      li_guo  sCKCrny5
# 2      li_guo  SY2FEqNj
# 3      li_guo  XXFI1LfP
# 4      li_guo  KZUHqEs8

# %%
train_author_name_paper_ids = train_author_paper_ids.merge(train_author_name_ids_ext, 'left', 'author_id')
train_author_name_paper_ids.head(2)
# Out:
#   author_id                                          paper_ids author_name
# 0  EShnTfSe                                         [P9a1gcvg]      li_guo
# 1  sCKCrny5  [Rg5fAeTd, lJPsGNBE, er5gTz90, UG32p2zs, FTweB...      li_guo

# %%
author_name_paper_ids = pd.concat([train_author_name_paper_ids, whole_author_name_paper_ids])
author_name_paper_ids = author_name_paper_ids.drop_duplicates(subset='author_id', keep='last')
author_name_paper_ids.head(2)
# Out:
#   author_id    author_name                                          paper_ids
# 0  004mBKh6  changsheng_li  [lRl7m2tU, 1vUnZLES, 5IbEOTRh, dVAKsHla, TY0MY...
# 1  008b5hIc   yuanyuan_liu                                         [nPuf0kYs]

# %%
author_name_paper_ids[author_name_paper_ids['author_id'] == 'EShnTfSe']
# Out:
#      author_id author_name   paper_ids
# 6111  EShnTfSe      li_guo  [P9a1gcvg]

# %%
# dict: {author_name:{paper_id:org}}
from collections import defaultdict
from tqdm import tqdm_notebook
author_org_map = defaultdict(dict)
author_id_org_map = defaultdict(list)
for author_id, author_name, paper_ids in tqdm_notebook(author_name_paper_ids[['author_id', 'author_name', 'paper_ids']].values):
    for pid in paper_ids:
        org = np.nan
        author_orgs = pub_info.loc[pid, 'authors']
        for ao in author_orgs:
            if not ao['name'] in author_name_map:
                continue
            if author_name_map[ao['name']] == author_name:
                org = ao.get('org')
        author_org_map[author_name][pid] = org
        author_id_org_map[author_id].append(org)
# Out:
# HBox(children=(IntProgress(value=0, max=25911), HTML(value='')))

# %%
author_org_map['li_guo']
# Out:
# {'5aWmjzF7': '',
#  'ncgx26VX': 'Inst. of Plasma Phys.',
#  'ukyDhct1': 'Institute of Plasma Physics',
#  'zCReRgCi': 'Institute of Plasma Physics',
#  'MSNMRJCQ': 'Institute of Plasma Physics',
#  'R4lQGPS1': 'Division of Solar Energy Materials and Engineering',
#  '2lFETYUf': 'Institute of Plasma Physics',
#  'R0EhOHO7': '',
#  'eSHL8y15': 'Institute of Plasma Physics',
#  '56xjEjtw': '',
#  '0DRE2SEL': 'Institute of Plasma Physics',
#  'ETx3SvN1': 'Institute of Plasma Physics',
#  '2005lDfL': '',
#  'gxFkYKbT': 'Institute of Plasma Physics',
#  '4hMURyAk': 'Institute of Plasma Physics',
#  'B00aSXLQ': 'Department of Ecosystem Science and Management, Pennsylvania State University',
#  'aXdjISJg': 'Department of Physiology',
#  'ffLBTHWJ': 'Puhuangyu Clinic',
#  '0h16kKyF': 'Nanjing Sport Institute',
#  'NcFYRcOD': 'Department of Environmental Science',
#  'ShgAjTFt': 'Department of Military Supplyment',
#  'Hl44JBg2': 'School of Resources and Environmental Science',
#  'WKGiaZ5U': '',
#  'qY8a1VoR': 'Department of Military Supplyment',
#  'VLQVUUvy': 'Research Institute of Bearings',
#  'qkFgMy3Y': 'Research Institute of Bearings',
#  'vTQNMUAO': 'Research Institute of Bearings',
#  'PKvvDIpa': 'Department of Medical Oncology',
#  'rSEXzjhh': '',
#  'dqc0USOy': 'Peking University First Hospital',
#  'ijUKk26R': 'Department of Radiology',
#  'i5JOvo9N': 'Department of Interventional Radiology',
#  'tVB9W3WR': 'Department of Radiology',
#  'heJsLgCz': '',
#  '6PfeRRVA': 'Department of Medical Imaging',
#  'sKzD6D1U': 'School of Economics and Management Engineering',
#  'MZWLfSc2': '',
#  't4733JLf': 'Department of Radiology',
#  'NWfMGqLT': 'Intervention Division',
#  't8kXuiOM': 'Department of Radiology',
#  'xkL5djmN': 'Department of Radiology',
#  '6qNCYoL7': '',
#  'syZRmJX7': 'Affiliated Tumor Hospital, Xinjiang Medical University',
#  'WwTT2wlJ': 'Department of Radiology',
#  'mq5YLe8I': 'Tianjin Key Laboratory of Food Biotechnology',
#  'wusLSr2K': '',
#  '6qmua6gQ': 'Department of Preventive Medicine',
#  'e3KtADX5': 'Department of Cell Biology and Genetics',
#  'E6xJAj0L': 'Department of Medical Genetics',
#  'pdOh3C5S': 'Shenyang Medical College',
#  'vh4OBBDY': 'Department of Cell Biology and Genetics, Shenyang Medical College',
#  'RE6JRql2': 'Department of Cell Biology and Genetics',
#  'Q83NxL6o': '',
#  'dhp6sPrt': '',
#  'YtLtzETC': '',
#  'CPL6CInC': 'Department of Medical Genetics',
#  '3NyjhKPM': 'Science Experimental Center, Shenyang Medical College',
#  'LuGMSRFC': 'State Key Laboratory of Environmental Criteria and Risk Assessment, Chinese Academy of Environmental Sciences',
#  'BfAVMEqJ': 'School of Material Science and Engineering',
#  'QDjAAHQc': 'Department of Chemical and Materials Engineering',
#  '2uwbCjFc': 'Institute of Chinese Materia Medica',
#  'PsWyN7W1': 'College of Mechanical Electrical and Information Engineering',
#  'qzkkJpc4': 'Department of Health Science and Nursing',
#  'Sx9zmexG': '',
#  'aP9CN0Y7': 'Department of Pathology',
#  'KSWtL3qS': 'Department of Pathology',
#  'hEv5Pb9a': '',
#  'zaiiJihL': 'College of Chemistry and Molecular Engineering, Zhengzhou University',
#  'Fb8k4EQh': 'Dept. of Physiology',
#  'MVfkF4dN': 'School of Economics and Management',
#  'anaOFVyy': 'Department of Epidemiology and Biostatistics, School of Public Health, Nanjing Medical University',
#  '1Iu0rTFQ': 'Department of Epidemiology and Biostatistics, School of Public Health, Nanjing Medical University',
#  'G7tIGExb': 'Department of Biostatistics, School of Public Health, Nanjing Medical University',
#  'DmP6773a': 'Department of Epidemiology and Biostatistics, School of Public Health, Nanjing Medical University',
#  'cBcVJh0z': 'Department of Epidemiology and Biostatistics, School of Public Health, Nanjing Medical University',
#  '3L6SZdIj': '',
#  'HHpcgUVt': 'School of Economics and Management Engineering, University of Civil Engineering and Architecture',
#  'oGfFbFXx': 'Luoyang Institute of Science and Technology',
#  'tQea3uFr': 'Luoyang Institute of Science and Technology',
#  'nCu5uuGn': 'Dept. of Civil Engineering',
#  'YZnqcO4q': '',
#  'ielMtHni': 'Department of Civil Engineering',
#  'jRmqrW9m': 'Luoyang Institute of Science and Technology',
#  '2UZZzILJ': 'Dept. of Civil Engineering',
#  'xINhbcY2': 'Luoyang Institute of Science and Technology',
#  'eJU331fp': 'Department of Civil Engineering',
#  '7eRnaW36': 'Luoyang Institute of Science and Technology',
#  'Ra36OIqk': 'Shaanxi Research Center of Engineering Technology for Clean Coal Conversion',
#  'CMoJ3V8A': '',
#  '5pXOVB6c': 'School of Chemical Engineering',
#  'gVRT5OOn': 'School of Chemical Eng., Chemical Engineering Res. Center of the Ministry of Education for Advanced',
#  'VT0ePAnp': 'School of Chemical Engineering',
#  'bDIREMaX': 'Institute of Agriculture of Shenyang Agricultural University',
#  'xqiIg2Nj': 'School of Textiles',
#  'TVTbKTLA': 'Ordnance Engineering Coll.',
#  'T0QaZmVv': 'Mechanical Engineering College',
#  'bJNT1e43': '',
#  'm7BRnkPN': 'Missile Engineering Department',
#  'Rq31QNs1': 'Mechanical Engineering College',
#  'PbmEGAlV': 'Key Laboratory of Advanced Textile Materials and Manufacturing Technology',
#  'mWgqUes7': 'Department of Pediatrics',
#  '2jgjlO8Q': 'Department of Pediatrics',
#  'yBhcbkbD': '',
#  '2dfAtKx3': '',
#  '2uKO1PPf': 'Department of Neurology, First Affiliated Hospital of Jinan University',
#  '37h5Yjlw': '',
#  'GFa9dRwv': 'Department of Endocrinology and Metabolism',
#  'J5KPOi3Y': 'College of Geological Exploration Prospecting Techniques of Beijing',
#  'ncKZv1RZ': 'Key Laboratory of Tea Biology and Resource Utilization, Ministry of Agriculture, Tea Research Institute, Chinese Academy of Agricultural Sciences',
#  'XYzMI4wf': 'Researtch Institute of Baosteel',
#  'Fn8jLLsI': 'Satellite Surveying and Mapping Application Center, NASG',
#  'TYpjEBEr': '',
#  'EtdhaYsH': 'Beijing University',
#  '5dhoKsvc': 'Peking University, Health Science Center',
#  'In2ln3Et': '',
#  'lKuAAYMn': 'Key Laboratory for Advanced Materials, Research Institute of Industrial Catalysis, East China University of Science and Technology',
#  'RcGk36ua': 'Key Laboratory for Advanced Materials',
#  'Xob81kWd': 'Key Laboratory for Advanced Materials',
#  'aRnpidP0': 'Key Laboratory for Advanced Materials, Research Institute of Industrial Catalysis, East China University of Science and Technology',
#  'N2z8m7J7': '',
#  'gRdwKmda': '',
#  'EvW3FKhC': 'Key Laboratory for Advanced Materials, Research Institute of Industrial Catalysis, East China University of Science and Technology',
#  'B8rrMwz4': '',
#  'HAiKlOz5': '',
#  '4hCQANPq': 'School of Economic and Management, Yan Shan University',
#  'PrbmCp81': 'Key Laboratory for Advanced Materials',
#  'KoFPUxWq': 'Key Laboratory for Advanced Materials, Research Institute of Industrial Catalysis, East China University of Science and Technology',
#  '6Qg5pESn': 'Key Laboratory for Advanced Materials, Research Institute of Industrial Catalysis, East China University of Science and Technology',
#  'tHUCxDQO': '',
#  'FfywQjq0': 'Key Laboratory for Advanced Materials',
#  'HBaadd7S': 'Laboratory of Nanophotonic Functional Materials and Devices (SIPSE), Laboratory of Quantum Engineering and Quantum Materials, South China Normal University',
#  '5tQ37ipF': '',
#  'LkM8DxZC': 'Internet and Cluster Computing Center',
#  'UvGwsqRV': 'Key Laboratory of Jiaxing Second Hospital',
#  'Ds2volkt': 'Department of Anesthesiology',
#  'u1UQFRLe': 'Department of Central Laboratory',
#  'pCzugUgE': 'Research Center',
#  'Phd7APE9': 'Central Laboratory',
#  'nRkHlC6K': 'Guang’anmen Hospital, China Academy of Chinese Medical Sciences',
#  'OxdJuZzT': '',
#  '0JYGNLEF': 'Ocean University of China, College of Marine Life Sciences',
#  'Er68TROT': 'College of Animal Science and Technique',
#  'U8x1h7ys': '',
#  'Waozw9Qh': 'Shandong Medical Imaging Research Institute',
#  'aInhRx1q': '',
#  'MuD6VT2w': 'Center for Health Management and Policy',
#  'v1tEkm2M': 'College of Food Science and Engineering',
#  'FlLxM2D6': 'School of Food Science and Engineering',
#  'VQBZxd7z': 'Department of Anaesthesiology, The First Affiliated of Harbin Medical University',
#  '4Y34jIm5': 'Intelligent Transportation System Research Center, Southeast University',
#  'fZxFyG1K': 'Chengdu University of Traditional Chinese Medicine',
#  '9kgK2ZYR': 'Department of Pediatrics',
#  'P9a1gcvg': 'Institute of Pharmacology and Toxicology',
#  'TfjjQ12J': '',
#  '3D4bP7z2': '',
#  'z2xPhliQ': 'Key Lab. of Fundamental Science for National Defense-Advanced Design Technology of Flight Vehicle',
#  'V30AtijQ': '',
#  'sXwkkTYe': 'College of Aerospace Engineering',
#  'u52Sgl4T': 'College of Material Science and Technology',
#  'BWRlSu3F': 'College of Aerospace Engineering',
#  'hoI37PSZ': 'School of Surveying and Spatial Information Systems',
#  'ZBl22C6e': 'School of Light Engineering, Anhui Agricultural University',
#  'oVUiib2X': 'School of Light Industry',
#  'gdo5E2vQ': 'Anhui Agricultural University',
#  'Zo5AAuJ5': '',
#  'SOutSaTj': 'School of Tea and Food Science and Technology',
#  'ffq4pT6s': '',
#  '4LAK6u7h': '',
#  '5y35ZeZi': 'State Key Laboratory of Bio-membrane and Membrane Biotechnology',
#  'E8Eiuclq': 'Department of Military Supplement, Military Economic Academy',
#  'y0J5QjXN': 'Department of Interventional Radiology, Second Hospital of Kunming Medical University',
#  'jkOjFl0e': 'Key Laboratory of Ecology of Rare and Endangered Species and Environmental Protection',
#  'vn8uort9': 'Key Laboratory of Smart Grid of Ministry of Education, Tianjin University',
#  '2DJCBW71': 'Key Laboratory of Smart Grid of Ministry of Education, Tianjin University',
#  'Gb54hp4m': 'Key Laboratory of Smart Grid of Ministry of Education, Tianjin University',
#  'OWAG49Xi': 'State Key Laboratory for Molecular Virology and Genetic Engineering',
#  'SWaWBpr6': 'MOH Key Laboratory of Systems Biology of Pathogens and Christophe Mérieux Laboratory',
#  'eCRSUwWJ': '',
#  '5eoW4xEs': 'Institute of Pathogen Biology',
#  'Uob3AJ6R': 'Ministry of Health Key Laboratory of Systems Biology of Pathogens, Institute of Pathogen Biology, Peking Union Medical College',
#  'bABxQBoP': 'State Key Laboratory of Molecular Virology and Genetic Engineering',
#  '2ySEbf1I': 'Ministry of Education Key Laboratory for Biodiversity Science and Ecological Engineering',
#  'X4dlYbm5': '',
#  'JMnIZmbC': 'Ministry of Education Key Laboratory for Biodiversity Science and Ecological Engineering',
#  'BLlyODfe': 'State Key Laboratory of Molecular Virology and Genetic Engineering',
#  'q4C9zYDj': 'MOH Key Laboratory of Systems Biology of Pathogens and Christophe Mérieux Laboratory, IPB, CAMS-Fondation Mérieux, Institute of Pathogen Biology (IPB), Chinese Academy of Medical Sciences (CAMS) and oPeking Union Medical College (PUMC)',
#  'JYkXXIy1': 'MOH Key Laboratory of Systems Biology of Pathogens',
#  'xtYxuWkD': '',
#  'w85dknXm': 'State Key Laboratory of Earth Surface Process and Resource Ecology',
#  'azZqveNS': '',
#  'UfHShSMN': 'State Key Laboratory for Molecular Virology and Genetic Engineering',
#  'Lu24PzhW': 'State Key Laboratory for Molecular Virology and Genetic Engineering',
#  '347GuXhV': 'MOH Key Laboratory of Systems Biology of Pathogens and Christophe Mérieux Laboratory',
#  '4hRPE8u4': '',
#  'plTO4BqY': 'MOH Key Laboratory of Systems Biology of Pathogens and Christophe Mérieux Laboratory',
#  'L5pCFNY4': 'State Key Lab. of Molecular Virology and Genetic Engineering',
#  '2OyQNTQV': 'National Institute for Viral Disease and Control and Prevention',
#  'XHQEEpeC': 'National Institute for Viral Disease Control and Prevention',
#  'cq65iV1v': 'Ministry of Education Key Laboratory for Biodiversity Science and Ecological Engineering',
#  '50TpeJlU': 'National Institute for Viral Disease Control and Prevention',
#  'zqmk4YLM': 'National Institute for Viral Disease Control and Prevention',
#  'e9ehOl9B': '',
#  'sWqz3mT0': 'State Key Laboratory of Molecular Virology and Genetic Engineering',
#  'DMkOLOoD': 'Institute of Pathogen Biology (IPB), Chinese Academy of Medical Sciences (CAMS), Peking Union Medical College (PUMC)',
#  'tdaysBqn': 'Institute of Laboratory Animal Science',
#  'tTFzHn0O': 'State Key Laboratory of Molecular Virology and Genetic Engineering',
#  'qu0L2cDo': '',
#  'b8htc9ZB': 'Christophe Mérieux Laboratory',
#  'ptIfzScM': 'State Key Laboratory of Molecular Virology and Genetic Engineering',
#  'MSErtepK': 'Mud Technology Service Co.',
#  'HNKMO1bQ': '',
#  '9uVoRdnY': 'Institute of Applied Catalysis',
#  'v2G8lRnw': 'State Key Laboratory Breeding Base of Systematic Research, Development and Utilization of Chinese Medicine Resources, Chengdu University of Traditional Chinese Medicine',
#  'wKRL4c7a': 'School of Pharmacy, Chengdu University of Traditional Chinese Medicine',
#  'b71E0Eon': 'State Key Laboratory Breeding Base of Systematic Research, Development and Utilization of Chinese Medicine Resources, College of Pharmacy, Chengdu University of Traditional Chinese Medicine',
#  'Z9fQOsX3': 'School of Pharmacy, Chengdu University of Traditional Chinese Medicine',
#  'NTJNlmlU': 'Pharmacy College, Chengdu University of Traditional Chinese Medicine',
#  '1uJhKJqE': 'State Key Laboratory Breeding Base of Systematic Research, Development and Utilization of Chinese Medicine Resources, Chengdu University of Traditional Chinese Medicine',
#  'RKfWL1Uk': 'State Key Lab. Breed. Base of Syst. Res., Development and Utilization of Chinese Medicine Resources, Chengdu University of Traditional Chinese Medicine',
#  'kw0Jh2Bs': 'State Key Laboratory Breeding Base of Systematic Research Development and Utilization of Chinese Medicine Resources, Chengdu University of Traditional Chinese Medicine',
#  'VCGvrwfB': 'Key Laboratory for Advanced Materials, Research Institute of Industrial Catalysis, East China University of Science and Technology',
#  'O4esvaUn': 'Key Laboratory for Advanced Materials, Research Institute of Industrial Catalysis, East China University of Science and Technology',
#  'rFM5KYdN': 'Key Laboratory for Advanced Materials, Research Institute of Industrial Catalysis, East China University of Science and Technology',
#  'gwOw5m4Y': 'Key Laboratory for Advanced Materials, Research Institute of Industrial Catalysis, East China University of Science and Technology',
#  'WNINMgQY': '',
#  '62yTK05l': 'Department of CT',
#  'jrukLD0q': 'Department of Medical Oncology, The Third Affiliated Hospital of Harbin Medical University',
#  '0qNwxJNV': 'Fifth Department of Oncology',
#  'Iy1E57AQ': 'Department of Medical Oncology, Harbin Medical University',
#  'e8lceLNC': '',
#  'm62cjORH': '',
#  'dIVYAcx7': 'College of Mathematics, Inner Mongolia University for Nationalities',
#  '7Tgnjo5R': 'College of Mathematics',
#  '5BO16piR': 'Lanzhou Petrochemical Engineering Corporation',
#  'urbi3JOh': '',
#  'cjB1WPRn': '',
#  'DwSCq20k': 'Key Lab of Advanced Processing and Manufacturing, School of Materials Science and Engineering, Tsinghua University',
#  '0rojyfeZ': 'Key Laboratory for Advanced Materials Processing Technology of Ministry of Education, School of Materials Science and Engineering, Tsinghua University',
#  'wD8jzbSs': 'Key Lab. of Advanced Processing and Manufacturing, School of Materials Science and Engineering, Tsinghua University',
#  'FvF7taCf': 'School of Materials Science and Engineering, Tsinghua University',
#  '2CblDqeT': 'Key Laboratory for Advanced Materials Processing Technology of Ministry of Education, School of Materials Science and Engineering, Tsinghua University',
#  'rtV2ZZqS': 'Key Lab. of Advanced Processing and Manufacturing',
#  'wYqdSBQg': 'Key Laboratory for Advanced Materials Processing Technology of Ministry of Education, School of Materials Science and Engineering, Tsinghua University',
#  'vsXkAxMX': 'Key Lab. of Advanced Processing and Manufacturing',
#  'lSyVfZpB': 'Key Laboratory for Advanced Materials Processing Technology of Ministry of Education, School of Materials Science and Engineering, Tsinghua University',
#  'ZLNnHGdI': 'School of Materials Science and Engineering, Tsinghua University',
#  '3RvFglud': '',
#  '9VctK804': 'Key Lab of Advanced Processing and Manufacturing',
#  'eBuh7cTv': 'Zhongshan Ophthalmic Center',
#  '3Vez4kTb': 'Zhongshan Ophthalmic Center',
#  'WTpMszgv': 'Ophthalmology Center',
#  '4r4hJNan': 'Zhongshan Ophthalmic Center',
#  'q6I5CrjK': 'Eye Res. Inst. Zhongshan Ophthal. C.',
#  'xUoVZJmz': 'Department of Ocular Genetics and Molecular Biology',
#  'u1BaKbeK': 'Zhongshan Ophthalmic Center',
#  'tfjd49jN': '',
#  'Oi0T3PBM': 'Beijing Institute',
#  'rx9yTPZM': '',
#  'Ly6DVUex': '',
#  '5DCNOsw2': '',
#  'I9FNsWdd': 'Beijing University of Chemical Technology',
#  'B3mGRDpC': '',
#  'JmuIMCfK': 'Department of Hematology Laboratory, First Affiliated Hospital, Shantou University Medical College',
#  'QwwVkqxm': '',
#  'DxwsTAgw': 'Department of Cell Biology and Genetics, Shantou University Medical College',
#  'msaHuMBg': '',
#  'qQyLn8j7': 'Department of Hematology Laboratory',
#  'TRB0qt0C': 'Department of Medical Engineering',
#  '59s21r7E': 'School of Management, China University of Mining and Technology, Xuzhou Institute of Technology',
#  'JI0z7Fl3': 'Electronic Engineering Department',
#  'ptNjaLKP': 'Xuzhou Institute of Technology',
#  'Hr8jLJ1L': 'Key Laboratory of Neurobiology',
#  'dsI2PPwf': 'State Key Laboratory of Multiphase Complex Systems, Institute of Process Engineering, Chinese Academy of Sciences',
#  't18lapg8': 'Shanghai Inst. of Ceramics',
#  'gz5NM7eR': 'Shanghai Institute of Ceramics',
#  'ijXjpqYT': 'Sch. of Environ. Studies',
#  'n6LzIFhS': 'Ford Foundation',
#  'MHtAbD9P': 'School of Chemical Engineering, Qinghai University',
#  'EWkMpnIL': 'School of Chemical Engineering, Qinghai University',
#  'KtfCka5D': '',
#  'F4FB5qq2': '',
#  'FCxNZGKV': 'School of Chemical Engineering, Qinghai University',
#  'BZkRf5KY': 'School of Chemical Engineering, Qinghai University',
#  'sZTvjy8s': '',
#  'zLAHcghB': '',
#  'zL4ha94K': 'Henan Zhengzhou Power Supply Company',
#  'cIfXhL7k': 'Xinxiang Environmental Monitoring Station',
#  'Ndq1lYTR': '',
#  'jmCgL5w0': 'Second Hospital',
#  'ppMg7FCD': 'Department of Traditional Chinese Medicine',
#  'ZwInlnkQ': 'Department of Applied Chemistry',
#  '63p5aB9Q': 'Foshan University',
#  'TKSTcqro': 'School of Kinesiology, Shanghai University of Sport',
#  'Rh0OJEVq': 'Affiliated Hospital of Inner Mongolia University for Nationalities',
#  'b6spluQU': 'Nanjing Telecommunication Technology Institute',
#  '8nMxxPyQ': 'Department of Orthopaedics, Second Hospital of Shanxi Medical University, Shanxi Key Laboratory of Bone and Soft Tissue Injury Repair',
#  'kGsYp4z8': 'State Key Lab. Breed. Base of Syst. Res., Development and Utilization of Chinese Medicine Resources',
#  'ZpP7BUVQ': 'Chengdu University of Traditional Chinese Medicine',
#  'aCZlv79w': 'School of Pharmacy, Chengdu University of Traditional Chinese Medicine',
#  'jul8BoeJ': 'Pharmacy College',
#  'X2P6UQ4s': 'Pharmacy College',
#  'NTDsrmDV': 'Pharmacy College',
#  'JNDS17ic': '',
#  'arZ6T8Z2': '',
#  '6Z2akkBq': 'College of Pharmacy',
#  'blMMgNed': 'School of Pharmacy, Chengdu University of Traditional Chinese Medicine',
#  'kjYa5bZE': 'Pharmacy College, Chengdu University of Traditional Chinese Medicine',
#  'w3stGjft': 'School of Pharmacy, Chengdu University of Traditional Chinese Medicine',
#  'Gv5mWKiO': 'Pharmacy College',
#  'KbxxAg08': 'Chengdu University of TCM',
#  'MvMZLEF2': '',
#  'EQLJLO6Q': 'Pharmacy College',
#  '137N04Uw': 'Wuhan Marine Electric Propulsion Research Institute',
#  'nNf6fxar': 'Novo Nordisk Research Center China',
#  'x9QpPS5c': 'Department of Marine Engineering',
#  'vQktY98i': '',
#  'WVp4vfnU': 'Marine Engineering College',
#  'XwnnuFow': '',
#  'IFxAAv3E': 'Marine Engineering College',
#  'JO9rqFsg': 'Henan Institute of Science and Technology',
#  '3diMT1ov': 'Department of Chemical and Biological Engineering, Institute of Biological Engineering, Zhejiang University',
#  'a7mL9bqF': 'Institute of Biological Engineering, Department of Chemical and Biological Engineering, Zhejiang University',
#  'u3GJwFeW': 'Department of Biomedical Engineering, Michigan Technological University',
#  '07yhX6LI': '',
#  '2EGB9ZLn': '',
#  'PdSmBWa0': 'Chinese National Engineering Laboratory for Information Security Technologies',
#  'IWY4IUR0': 'Institute of Information Engineering, Chinese Academy of Sciences, National Engineering Laboratory for Information Security Technologies',
#  'VJiDYgC6': 'Institute of Information Engineering, Chinese Academy of Science',
#  'VNdz0DMW': 'School of Public Health, Jilin University',
#  'vNolPjau': 'College of Electrical Engineering, Chongqing University of Posts and Telecommunications',
#  'HFfIetme': 'Zhejiang Chemical Industry Research Institute',
#  'HpWpalfo': 'Zhejiang Chemical Industry Research Institute',
#  'lOohFwkL': 'Zhejiang Chemical Industry Research Institute',
#  'gg5Tfd0u': 'Zhejiang Chemical Industry Research Institute Co., Ltd.',
#  'fj4MO6WG': "School of Environment & Chemical Engineering, Xi'an Polytechnic University",
#  'IOmOofcw': "School of Environmental and Chemical Engineering, Xi'An Polytechnic University",
#  'qMdNW8oj': 'School of Chemistry and Material Science',
#  'pVulK9RF': 'Key Lab. of Catalysis and Mat. Sci. of the State Ethnic Affairs Commission & Mini. of Educ., School of Chemistry and Material Science, South Central University for Nationalities',
#  'VFAEpVXX': 'School of Chemistry and Material Science, Key Lab. of Catalys. and Mat. Sci. of the State Ethnic Affairs Commission and Ministry of Education, South Central University for Nationalities',
#  'VOm1IioC': '',
#  '6rffTXXR': '',
#  'WEtXwdvY': '',
#  'oHzdj1Iz': 'Department of Aviation Oil and Material, Air Force Logistics College',
#  '9JsRXkap': 'Air Force Service College',
#  'iThMb8Zz': '',
#  'C3gStKJS': 'Institute of Chemical Engineering and Textile',
#  'vJ6n3nTu': 'Environment Science and Engineer College of Shandong University',
#  'l55SZ0d5': 'Department of Textile and Chemical Engineering',
#  'tk4zVMQe': 'Department of Textile and Chemical Engineering',
#  'EWNPuWC0': 'Binzhou Vocational College',
#  'T4nGsTfN': 'State Key Laboratory of Non-linear Mechanics, Institute of Mechanics, Chinese Academy of Sciences',
#  '6tRGVteu': "Xi'an Geological Survey Center",
#  'fH0fb6t5': 'Institute of Information Engineering, Chinese Academy of Science',
#  'NpHrRzDM': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'minbslDC': '',
#  'SZshJm3L': 'National Engineering Laboratory for Information Security Technologies',
#  'kXgsOWiZ': '',
#  'HqvMR3Ny': '',
#  'CT4pU9on': '',
#  'sWH7iocZ': 'Department of Psychiatry',
#  'dsmzVoTO': 'Key Laboratory of Tea Biology and Resources Utilization',
#  'zRLpIzot': '',
#  'nX4MytZs': '',
#  'GL0rG3Al': 'State Key Laboratory for Molecular Biology of Special Economic Animals, Institute of Special Economic Animals and Plants, Jingyue Economic Development Zone, Chinese Academy of Agricultural Sciences CAAS',
#  'emughQ2w': 'State Key Laboratory for Molecular Biology of Special Economic Animals',
#  'EnXhly7A': 'Key Laboratory of Tea Biology and Resource Utilization',
#  '1M7mYgmR': 'Key Laboratory of Tea Biology and Resources Utilization, Ministry of Agriculture, Tea Research Institute, Chinese Academy of Agricultural Sciences',
#  'EDwy7wwy': '',
#  'IJ5BQzeZ': '',
#  'OFsC3oks': 'Key Laboratory of Tea Biology and Resource Utilization of Ministry of Agriculture, Tea Research Institute, Chinese Academy of Agricultural Sciences',
#  'zD9JVheL': '',
#  'ykskRKyu': '',
#  'FBZKbp3Z': '',
#  'pvWEpw5K': '',
#  '4Rfh7Tce': 'Ministry of Water Resources',
#  'N2JySeE0': 'Department of Atmospheric and Oceanic Sciences',
#  'Tga7xuSn': 'Department of Biology and Chemistry',
#  'FGoS1ZgU': 'School of Mechanical Engineering, Dalian University of Technology',
#  'v6t3XniR': 'Key Laboratory of MEMS of Ministry of Education, Southeast University',
#  'xaOc5pyc': 'Institute of Information Engineering',
#  '7vnVloWp': 'Department of Engineering Mechanics',
#  '3v31b4cy': 'Shanghai Astronomical Observatory',
#  'NPE50Zvx': 'Department of Ophthalmology, Mianyang Central Hospital',
#  'LzNSYqOn': '',
#  'SfQ1ZUO4': 'School of Information Engineering',
#  'NFjZ1rme': 'Department of Physics and Mathematics',
#  'loeZWfHO': '',
#  '1UElUN0w': '',
#  'S9Y8YNNq': 'University of Science and Technology of China',
#  'QN3k4bBs': 'Dept. of Electronic Science and Technology',
#  'XZgEHNGn': 'Department of Epidemiology and Biostatistics',
#  'NpJLwJwG': 'Nanoscale Physics and Devices Laboratory',
#  'fUCONiNh': '',
#  '5s5hp9VN': 'State Key Laboratory of Multiphase Complex Systems',
#  '7tqmjPnw': '',
#  'ugaUtd54': 'Tianjin University',
#  'hF2XjiYL': 'State Key Laboratory of Bioelectronics',
#  '9bTBW5EU': 'Institute of Information Engineering',
#  'wJ3CeHQG': 'South China University of Technology',
#  'v0R2x6eJ': 'Institute of Information Engineering',
#  '8vjsM46I': 'Accounting Education Dept.',
#  'CSIpPLwJ': 'Institute of Information Engineering',
#  'IdrzcqD5': 'Multi-Phase Reaction Laboratory',
#  'yJ7vfnQZ': 'School of Information Science and Engineering',
#  'rrUjfIh3': 'Institute of Computing Technology',
#  'gJQ2vPrU': 'Key Laboratory of Information Processing and Intelligent Technology',
#  'QeYu2oe4': 'State Key Laboratory of Earth Surface Processes and Resources Ecology',
#  'NLzQzL3H': 'State Key Laboratory of Earth Surface Processes and Resource Ecology',
#  '2IbTRcE8': 'Institute of Computing Technology',
#  'GSwb2A2E': 'Department of Chemistry',
#  '0x4UFcQJ': 'Department of Electronic Science and Technology',
#  'i8iXii9C': '',
#  'g2a7ae8r': 'Department of Enzymology',
#  'C0LwTl95': 'Department of Enzymology',
#  'AgSOUlgJ': '',
#  'NOyUwxde': 'National Engineering Laboratory for Information Security Technologies',
#  'xHZ3HnY4': 'Research Center of Information Security',
#  '5zfRbbAS': 'State Key Laboratory of Bioelectronics',
#  'hCGamDSk': 'Institute of Computing Technology',
#  'RTPjw6rD': 'Department of Medical Imaging',
#  'zPhlsTlk': '',
#  '6n0hLwgt': 'Department of Neurology, Second Hospital of Hebei Medical University',
#  'NhY5YT6K': 'School of Mechanical and Power Engineering',
#  '1C8b6HPi': 'Department of Electronic Science and Technology',
#  'ovIo75Hm': '',
#  'J9qN6a47': 'School of Electronic Engineering University',
#  '4bquMKnE': 'College of Mechanical and Vehicle Engineering',
#  'I8vkQFgg': 'Key Lab. of Universal Wireless Communications',
#  'LxXABfAe': 'Institute of Information Engineering',
#  'yV5aVpIb': 'College of Information Science and Engineering',
#  'JY4Wv0Q2': 'School of Civil Engineering',
#  'dMTxr6Ku': 'National Engineering Research Center for High Efficiency Grinding',
#  'cejqE1Xz': 'Hunan University',
#  '9UAVuGbV': 'University of Electronic Science and Technology',
#  'ptJ8iC4s': 'School of Civil Engineering',
#  'sVUIWIwo': 'Department of Epidemiology and Biostatistics, School of Public Health, Nanjing Medical University',
#  '4AazLuSu': 'School of Resource and Safety Engineering, China University of Mining and Technology (Beijing)',
#  '4bfvKutu': 'Key Laboratory of Smart Grid',
#  'e7MrFwU9': '',
#  'fF47CAhs': 'Key Laboratory of Universal Wireless Communications',
#  't8zBKwU8': 'Renji Hospital, Shanghai Jiaotong University, School of Medicine',
#  'K1nZYPAQ': 'National Engineering Laboratory for Information Security Technologies',
#  'KXrg5Uqk': 'Institute of Computing Technology',
#  'TkY7z7ak': '',
#  'RTaxYssq': '',
#  'Oo7qtbRe': 'State Key Laboratory of Microbial Resources, Institute of Microbiology',
#  'FI4J4ABl': 'Key Laboratory of Smart Grid of Ministry of Education',
#  'A1r2yKn1': '',
#  '3YF44vdt': 'Institute of Computing Technology',
#  'UXZx2m8c': 'College of Resources and Environment, University of Chinese Academy of Sciences',
#  'eHpeljc4': 'Institute of Computing Technology',
#  'OobupJTn': 'Department of Medical Imaging',
#  '4L7NPPok': 'School of Civil Engineering',
#  'EL8bZRjo': 'Beijing University of Post and Telecommunication',
#  'nGWguFDC': 'Institute of Computing Technology',
#  'tLWwSkZD': 'Dept. of Electron. Sci. and Technol.',
#  'pRQ9t5J3': 'Institute of Information Engineering, Chinese Academy of Sciences (CAS), National Engineering Laboratory for Information Security Technologies',
#  'ahunIlLk': 'National Engineering Laboratory for Information Security Technologies, Institute of Information Engineering, Chinese Academy of Sciences',
#  'a0ORGCfv': '',
#  'SglYZZBf': 'Department of Electronic Science and Technology',
#  'T9k9gyAa': 'School of Mechanical Engineering, Dalian University of Technology',
#  '1DReERU1': 'Department of Neurology',
#  'y70Ihwsy': 'Institute of Computing Technology',
#  'mwtmMZRO': 'Institute of Computing Technology',
#  '9r8237Me': '',
#  'EtpMip34': 'Second Hospital of Hebei Medical University',
#  'qNZBGrCj': '',
#  'HKKdJNkt': 'School of Engineering and Science',
#  'CMZxVted': 'Institute of Information Engineering',
#  '3tEBIRaV': 'National Engineering Laboratory for Information Security Technologies',
#  'xy1DEhLQ': 'Dept of Computer Science',
#  'iYlwmoNZ': 'National Engineering Research Center for High Efficiency Grinding',
#  'ReAtzuUY': '',
#  'u95Pp3u3': 'National Engineering Laboratory for Information Security Technologies',
#  'tdWps9As': 'College of Gardening',
#  'LrjlAKW5': 'Shanghai Astronomical Observatory',
#  'vC8OfQ7g': '',
#  'b0D0ggzN': '',
#  'qv1W41P2': '',
#  '5SCyXqdm': 'National Engineering Laboratory for Information Security Technologies',
#  'XgESpoXG': '',
#  'kH8lpU7k': 'School of Electrical Engineering and Automation',
#  'DteSVGzR': 'State Key Laboratory for Structural Chemistry of Unstable and Stable Species',
#  'kuy1jk7Z': 'School of Information Science and Technology',
#  '7609LUea': 'Department of Computer',
#  'hF56Jaao': 'Chinese National Engineering Laboratory for Information Security Technologies',
#  'JWE4TXT4': 'Department of Electronic Science and Technology',
#  'DP4seN9E': 'Key Lab of Universal Wireless Communications',
#  'RX2PJ5M8': 'Institute of Information Engineering',
#  'eWzZTXWk': '',
#  'b69Szrvk': '',
#  'n7a5jQGs': 'Department of Neurology, Jinan University',
#  'mLEbcaXV': 'BUPT',
#  '1nCcaMa7': 'Jiangsu Key Laboratory of Engineering Mechanics, Southeast University',
#  'hutAdPpc': 'Department of Electronic Science and Technology',
#  'SDIDqrDO': '',
#  'Bkp7ihPs': 'Department of Neurology',
#  '7YaSqCMV': 'School of Chemistry and Pharmaceutical Engineering',
#  'UexeaPwW': 'State Key Laboratory of Bioelectronics',
#  'F0kxzmzv': '',
#  'gqCWhmhe': 'Department of Epidemiology and Biostatistics, School of Public Health, Nanjing Medical University',
#  '1XW9337C': "Division of Rheumatology, Children's Hospital of Zhejiang University School of Medicine",
#  'YXdCPzJ2': 'School of Computer and Communications',
#  'y0GAbfbQ': 'Research Center for Information Intelligence and Information Security',
#  'Wetxm3t7': '',
#  'y34fINSp': 'Synergistic Innovation Center of Chemistry and Chemical Engineering of Tianjin',
#  'Ko7qJfVr': 'College of Information Science and Engineering',
#  'DvTHB4UK': '',
#  '0PpNSOF7': 'Institute of Information Engineering',
#  'Sg0Pvl4s': 'Department of Electronic Science and Technology',
#  'shfciom4': '',
#  'PXSu4b5H': 'CSEE',
#  '6AQtIkGY': 'National Engineering Laboratory for Information Security Technologies',
#  '2fwWSo88': 'Coll. of Mech. and Automotive Eng.',
#  '8fwsTrUd': 'National Engineering Laboratory for Information Security Technologies',
#  '7RjrxRVD': 'Department of Electrical Engineering',
#  'rpAMFeYf': '',
#  'dTOzVEj4': 'National Engineering Laboratory for Information Security Technologies',
#  'RVvAFgqw': 'National Engineering Laboratory for Information Security Technologies, Institute of Information Engineering, Chinese Academy of Sciences',
#  'sH85PV8U': 'College of Information Science and Engineering',
#  '0o5ZuI1q': 'Institute of Computing Technology',
#  'B7gcfJj8': 'State Key Laboratory of Microbial Resources',
#  'viKTzt0x': 'State Key Laboratory of Multi-Phase Complex System',
#  'Kp7TZL9l': 'Department of Electronic Science and Technology',
#  'aSqmClGz': 'Department of Chemistry',
#  'u8LdAnnN': 'Institute of Information Engineering',
#  'NyfUt1Nx': '',
#  'f86aayUM': 'Institute of Computing Technology',
#  'HVe572N0': 'National Engineering Laboratory for Information Security Technologies',
#  'EomPOROn': 'Shanghai Astronomical Observatory',
#  'dpvRFISU': 'School of Civil Engineering',
#  'lVhsVEJj': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'su5dXitd': 'College of Information Science and Engineering',
#  'Ne5kZHXn': 'Graduate School',
#  'j0xsYN8v': '',
#  'nNiMjv7s': 'Dept. of Electron. Sci. and Technol.',
#  'n6G1a82m': 'Tianjin Key Laboratory of Aqua-ecology and Aquaculture',
#  'MUTF2Sjw': 'State Key Laboratory of Bioelectronics',
#  'tk2tf68q': '',
#  'IUNCzUCT': 'Department of Electronic Science and Technology',
#  'SMrSTvFA': 'Institute of Information Engineering',
#  'L26g17o8': '',
#  'ALF3tsTK': 'School of Electronic Science and Technology',
#  'M8ziyInc': 'National Engineering Laboratory for Information Security Technologies',
#  '1A7zdJME': 'Univ. of Science and Technology of China',
#  'WhZiJ13C': '',
#  'wrguEdEL': 'School of Medical Imaging',
#  'onBOItSU': 'Department of Electronic Science and Technology',
#  'mO4rXXob': 'Department of Computer-Science',
#  'iMjbcMtm': 'School of Medical Imaging, Tianjin Medical University',
#  '2vnzNlZv': 'Institute of Computing Technology',
#  'OugDwxmO': 'Key Laboratory of Smart Grid of Ministry of Education (Tianjin University)',
#  '2j7eBdaC': '',
#  'zsXJ1pXE': 'State Key Laboratory of Multiphase Complex Systems',
#  'ZMsTX2Gl': 'Graduate University of Chinese Academy of Sciences',
#  'L528w3Iz': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'JcwrT3wX': '',
#  'hCQM1O7h': 'Department of Electronic Science and Technology',
#  '6krp5I4c': '',
#  'o2m6aVp1': 'Institute of Computing Technology',
#  'PyfzyKXg': 'Department of Electronic Science and Technology',
#  'LmCoI7er': 'Computer Science and Technology School',
#  'aO5t8UlR': '',
#  'kcAAnlu1': 'Institute of Computing Technology',
#  'nCSjnLpL': 'Key Laboratory of Hebei Neurology',
#  'QIzh199p': '',
#  'YzcvX7PV': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'CSORnkyB': '',
#  'aHRYTSYk': 'Department of Neurology',
#  'tAYxnfFq': 'State Key Laboratory of Microbial Resources',
#  '3SPMYnKo': 'Institute of Information Engineering',
#  'NmmaZtRS': '',
#  'g79p5DYL': 'State Key Laboratory for Molecular Biology of Special Economic Animals, Institute of Special Wild Economic Animal and Plant Science, Chinese Academy of Agricultural Sciences',
#  'Y5SyAEud': '',
#  'CChvmOsX': 'Department of Electronic Science and Technology',
#  '6CkNwsJH': '',
#  '5LU9jWAD': 'Project Management and E-Commerce Laboratory',
#  'e2OQ2ppJ': 'Geographic Space Information Institute of Information Engineering University',
#  'NrwaAwrh': 'Key Lab of Universal Wireless Communications',
#  'EtFK7Uja': 'Institute of Computing Technology',
#  'TdDTJ6GL': 'State Key Laboratory of Bioelectronics',
#  '0VRxhSM2': 'Institute of Computing Technology',
#  '4szP9Hkb': 'Institute of Computing Technology',
#  'MsydSyYP': 'Key Laboratory of Power System Simulation and Control of Ministry of Education',
#  'WRVHuioT': 'State Key Laboratory of Earth Surface Processes and Resource Ecology',
#  'RG2AG1LY': 'China Key Lab. of Universal Wireless Communications',
#  'b1d7bv47': 'Institute of Information Engineering',
#  'wd3ugFQM': '',
#  'uKo6MoJA': '',
#  'SmnS6qwa': 'Institution of Surveying and Mapping',
#  'PT14nnmM': 'Dept. of Comp. Sci. and Technol.',
#  'vKhZWMKD': 'State Key Laboratory',
#  'PFbIYlwn': 'Institute of Information Engineering, Chinese Academy of Science',
#  'OYNHpugv': 'Department of Electronic Science and Technology, University of Science and Technology of China',
#  'KZUNApU6': 'School of Computer Science and Technology, Harbin Institute of Technology',
#  '7Y3cXLi3': 'Key Laboratory of Power System Simulation and Control of Ministry of Education',
#  'DotZ14k5': 'Institute of Surveying and Mapping',
#  'bnf1AEBy': 'Key Laboratory of Smart Grid of Ministry of Education',
#  'eEHIckau': 'State Key Laboratory of Bioelectronics',
#  'u8qF4NY0': 'Northeastern University',
#  'cuttYQYB': 'China Aluminum Corporation',
#  'YekNjakc': 'National Engineering Research Center for High Efficiency Grinding',
#  '0c59AKMN': 'Dept. of Electron. Sci. and Technol.',
#  'LMEMoXPl': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'wnlWrHFQ': 'Key Laboratory of MEMS of Ministry of Education, Southeast University',
#  'He2GBIzP': '',
#  'io0u3eYP': 'Department of Epidemiology and Biostatistics',
#  'UjHfaIcp': 'Department of Electronic Science and Technology',
#  'wyQz0917': 'Key Laboratory of Smart Grid of Ministry of Education, Tianjin University',
#  'gdEJfSxy': 'School of Information Science and Engineering',
#  'FGlQYwH1': 'Department of Electronic Science and Technology',
#  'VRSujBEK': '',
#  '61hZEeCE': 'School of Mechanical Engineering',
#  'vQrFArRE': 'College of Information Science and Engineering',
#  '7hdAu1pA': 'Dongling School of Economics and Management, University of Science and Technology Beijing',
#  'fNUnpAiW': '',
#  'L6ML9PnV': 'State Key Laboratory of Microbial Resources, Institute of Microbiology, Chinese Academy of Sciences',
#  'OsMEdLTX': 'Department of Electronic Science and Technology',
#  'YjkQokOI': '',
#  '650K1IKJ': '',
#  'm11z5wRK': 'Department of Engineering Mechanics',
#  'NIlQq0do': 'Department of Electronic Science and Technology',
#  'psWv89cs': 'Key Laboratory of Smart Grid of Ministry of Education (Tianjin University)',
#  'obWJCXcw': '',
#  'CAlzkTTg': 'Department of Neurology, The Second Hospital of Hebei Medical University, Key Laboratory of Hebei Neurology',
#  'xbXftRyX': 'National Engineering Research Center for High Efficiency Grinding',
#  'ceGwETv1': 'Department of Chemistry',
#  'fb5WVyYS': 'Department of Electronic Science and Technology',
#  '3ESQ9t8n': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'vPk5IQde': 'Chinese National Engineering Laboratory for Information Security Technologies',
#  'O1udNhn5': 'State Key Laboratory of Multiphase Complex Systems, Institute of Process Engineering, Chinese Academy of Sciences',
#  'Ki1KROA5': '',
#  'yZM2MDyI': 'State Key Laboratory for Structural Chemistry of Unstable and Stable Species',
#  'oXvcf7Yy': 'Department of Electronic Science and Technology',
#  'Jm1cipEA': 'Information Engineering University',
#  'ox2j44ES': 'College of Global Change and Earth System Science, Beijing Normal University',
#  'pumJhWg0': 'College of Information Science and Engineering',
#  'O91kPEmr': '',
#  'tVa6zxss': 'Key Laboratory of Smart Grid of Ministry of Education',
#  'VCQ0LI5F': '',
#  '29oOHzk2': 'Institute of Information Engineering, Chinese Academy of Sciences, National Engineering Laboratory for Information Security Technologies',
#  'zbfH95CR': 'National Engineering Laboratory for Information Security Technologies',
#  'N1Ate7XC': 'State Key Laboratory of Microbial Resources',
#  'gpB2k7Qf': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'QrXaABMq': 'Institute of Computing Technology',
#  'fbQBv72y': 'Graduate School of Chinese Academy of Sciences',
#  '9dSBwex5': 'State Key Laboratory of Bioelectronics',
#  'NLdTJ3Aw': 'Key Laboratory of Smart Grid of Ministry of Education, Tianjin University',
#  'QLFXLSBn': '',
#  'FaOHQomC': 'Department of Electronic Science and Technology',
#  'bO0bSG42': 'Institute of Computing Technology',
#  'OC75tozy': 'Institute of Computing Technology',
#  'OomaIR1l': '',
#  'pYKTrEQj': 'Meclianical and Automotive College',
#  'UyIEYExq': 'School of Electronic Engineering',
#  'jY3gfBhM': 'State Key Laboratory of Multiphase Complex Systems',
#  'VYHUYrZr': 'Key Laboratory of Universal Wireless Communication',
#  'QI1FYBan': '',
#  'b951RBDS': 'Zhengzhou Institute of Surveying and Mapping',
#  'bVx0YlsZ': '',
#  'GIHEvHs0': 'Key Laboratory of Specially Functional Materials',
#  'aW8aHIop': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'kmyawALz': '',
#  'SRI7n95m': '',
#  'iBBAoxYR': 'Key Laboratory for Quantum Optics and Centre for Cold Atom Physics, Shanghai Institute of Optics and Fine Mechanics',
#  'kK4AajEy': 'Key laboratory of MEMS of Ministry of Education, Southeast University',
#  '7vM4yW9q': 'National Engineering Laboratory for Information Security Technology',
#  'LWyELvVX': 'School of Medical Imaging',
#  'wmJxB9Mo': 'State Key Laboratory of Microbial Resources',
#  'ayB9XsKD': 'Key Laboratory of Smart Grid of Ministry of Education',
#  'jvLIVOC0': 'Department of Electronic Science and Technology',
#  '9uamRFdG': 'Institute of Information Engineering',
#  'HeyxX0f0': '',
#  'oC4VVgwz': 'Key Lab of Universal Wireless Communications',
#  'EPPflE1m': 'School of Computer Science',
#  'Spe4cNug': 'School of Sciences, Beijing University of Post and Telecommunication',
#  'GEKub54L': 'Institute of Information Engineering, Chinese Academy of Science',
#  'quSx7adm': 'Software Laboratory, Institute of Computing Technology, Chinese Academy of Sciences',
#  'rslLc31e': 'Department of Medical Imaging',
#  'XkOi0KvB': 'Institute of Information Engineering Chinese Academy of Sciences',
#  'LOmQ3AOk': 'Shanghai Astronomical Observatory, Chinese Academy of Sciences',
#  'SMts74hZ': 'Key Laboratory of Smart Grid of Ministry of Education',
#  'zEurWWVC': '',
#  'weyBzXBA': 'Key Laboratory of Universal Wireless Communications, Beijing University of Posts and Telecommunications',
#  'kuxZTUjD': 'Department of Neurology',
#  'q9M4ZfYO': 'Dept. of Electronic Science and Technology',
#  'fU272nFV': 'China National Engineering Research Center for High Efficiency Grinding',
#  'NIhBL35s': 'Co-innovation Center of Chemistry and Chemical Engineering of Tianjin',
#  'jMErL46k': 'Department of Enzymology',
#  'Xj8LTpH8': 'National Engineering Laboratory for Information Security Technologies',
#  'CN3GDvKV': 'Institute of Computing Technology',
#  'k92LILuK': 'School of Information Engineering',
#  'qyDSQnRl': 'Software Division',
#  'E2vuQWE9': 'Key Lab. of Universal Wireless Communications',
#  'z9zijkiD': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'UUXzwPur': 'Department of Epidemiology and Biostatistics, School of Public Health, Nanjing Medical University',
#  'r3Lk6rTV': 'Institute of Computing Technology',
#  'xbWbCsnP': 'School of Electrical Engineering',
#  'VmbaXUbP': 'State Key Laboratory of Microbial Resources',
#  'v8VeZwHC': 'State Key Laboratory of Multiphase Complex Systems',
#  'fxFky1gR': 'Institute of Computing Technology',
#  'd7In4ZTV': 'School of Information Engineering',
#  'RwhUkso0': 'Harbin Institute of Technology at Weihai',
#  'pTdK43q9': 'Dept. of Electronic Science and Technology',
#  'BX4Landt': 'Department of Electronic Science and Technology',
#  'qjOmoC26': 'Institute of Navigation, Guidance and Control',
#  'zcAdFTk8': 'Department of Electronic Science and Technology',
#  'ckSre7b6': 'Department of Computer Science',
#  '0EHH7O76': 'Key Laboratory of Smart Grid of Ministry of Education (Tianjin University)',
#  '553JJzQx': 'Dept. Electronic Science and Technology',
#  'iPjFYOkM': 'School of Electrical Engineering and Automation',
#  '5lTcHZZF': 'Department of Electronic Science and Technology',
#  'C36ilqV8': '',
#  'C7QxLMpA': 'Department of Epidemiology and Biostatistics, School of Public Health, Nanjing Medical University',
#  'Xy1kmCeA': '',
#  'CSYThirC': '',
#  'IRg23E50': 'State Key Laboratory of Earth Surface Processes and Resource Ecology',
#  'XtpTh8q5': '',
#  '8a1YPO1b': 'Coll. of Civil Eng.',
#  'wMbPaTRP': 'State Key Laboratory of Earth Surface Processes and Resource Ecology',
#  'sh3WDAl5': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'a6q9U35z': 'College of Information Science and Engineering',
#  '0eqCBR9X': 'Department of Epidemiology and Biostatistics',
#  'xGti30IS': 'Department of Neurology',
#  'IbADJ2b2': '',
#  '3DiYOwKM': '',
#  't44kgXg5': 'Department of Epidemiology and Biostatistics',
#  'sHL2Q9pT': '',
#  'f9eIkACp': 'Tianjin Key Laboratory of Applied Catalysis Science and Technology',
#  'Ytt2kvui': 'Institute of Information Engineering, Chinese Academy of Science',
#  'bZuh6hfV': 'Key Laboratory of Smart Grid of Ministry of Education',
#  '50ZqY11O': 'School of Information Engineering',
#  'Mna0Nu47': 'School of Mech. Eng.',
#  '63tLpQkM': 'State Key Laboratory of Multiphase Complex Systems',
#  'cupRn2kO': 'Department of Electrical Engineering and Automation',
#  '9XYPVdX9': 'National Engineering Laboratory for Information Security Technologies',
#  'qYYYeFbf': 'Institute of Physical Chemistry',
#  'AW1lSW3X': '',
#  'ZfWi1qPi': '',
#  'DpBMldvG': 'School of Mechanical Engineering, Dalian University of Technology',
#  'tKItKyLp': 'Key Laboratory of Smart Grid of Ministry of Education',
#  'b6L5kmwf': '',
#  'JFT5cELC': 'Institute of Computing Technology',
#  'tKcpXvCD': 'Institute of Computing Technology',
#  'Wq58VaSV': 'Department of Electronic Science and Technology',
#  '30tCDKHi': 'Institute of Computing Technology',
#  'Cm69vhO7': 'Department of Neurology',
#  'u75386bh': '',
#  'FnvGglJj': 'Key Laboratory of Smart Grid of Ministry of Education, Tianjin University',
#  'BEV3WyY7': 'Department of Engineering Mechanics',
#  'mmwwFKJ3': 'Electric Power College',
#  'AYZpLA6c': 'Faculty of Metallurgical and Energy Engineering',
#  '3dDmr3xC': 'School of Geodesy and geomatics',
#  'TfKL1KeL': 'University of Science and Technology of China',
#  'Os3gi86G': '',
#  'a5M2bLpK': 'Graduate University',
#  'h0ZTphVI': '',
#  'xssDWuIz': 'Key Laboratory of Smart Grid of Ministry of Education, Tianjin University',
#  'kMO2ex8C': 'State Key Lab. Struct. Chem. of USS',
#  'MB6l72WY': 'State Key Laboratory of Bioelectronics',
#  'B998ur3s': 'Key Lab. of Universal Wireless Communications',
#  '6UjTZSZV': 'Information Security Center',
#  'WqZEGAyW': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'ZUfWc0Zj': 'Southeast University',
#  '5etdb3ce': '',
#  'rCW75VKV': '',
#  'trQ59VT7': 'School of Information Engineering',
#  'zZ9LkVa9': 'Department of Electronic Science and Technology',
#  'LaHar5Mp': '',
#  'vDG4mUin': 'Graduate School',
#  'aqLNZqq0': 'Department of Computer Science',
#  'RfEPNxQF': '',
#  'hmVUc4ff': 'Department of Electronic Science and Technology',
#  '8lF1NiLY': 'Key Laboratory of Smart Grid of Ministry of Education',
#  'kbMjnBiM': 'Institute of Computing Technology',
#  '1yu8n8Sn': 'School of Mechanical Engineering',
#  'G03fNp3q': 'Institute of Information Engineering',
#  'IlVK4V92': 'Institute of Computing Technology',
#  'XcBDxyJy': '',
#  'Cvtp87pj': 'Institute of Information Engineering',
#  'mfFsSoHG': 'Medical Imaging Department, Tianjin Medical University',
#  'Y1luRQAY': 'School of Electronic Science and Technology, Dalian University of Technology',
#  'xYpXgCwE': 'Inst. of Lasers and Optoelectron.',
#  '4QqtDB96': 'Lab. of Advanced Technology for Vehicle Body Design and Manufacture',
#  'cmNyH3Nk': 'Second Hospital of Hebei Medical University',
#  'fWchSFis': 'National Engineering Laboratory for Information Security Technologies',
#  'jvKMPeLe': 'State Key Laboratory of Multiphase Complex Systems',
#  't7B2jSOU': 'National Engineering Laboratory for Information Security Technologies',
#  'lEeQfPA9': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'vI20HNPK': 'Department of Electronic Science and Technology',
#  '7ZSVms6V': 'South China University of Technology',
#  '8uNsOPmA': 'Inst. of Process Eng.',
#  'V6rzJ3mM': 'Deptartmen of Electronic Science and Technology',
#  'iRfLD9aI': 'Institute of Computing Technology',
#  'DfkdH0ye': 'College of Medical Imaging',
#  'SOaEz6v5': 'Institute of Process Engineering',
#  'l2pO7SyJ': 'School of Management and Economics, University of Electronic Science and Technology of China',
#  't66LMHjV': 'Graduate School',
#  'JyPeON2b': 'Key Laboratory of Smart Grid of Ministry of Education, Tianjin University',
#  'P0b8ZSHU': 'National Engineering Laboratory for Information Security Technologies',
#  'F6wSAPsc': 'National Engineering Laboratory for Information Security Technologies',
#  '09BsvVfS': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'fMWVHh9p': 'School of Electrical Engineering and Automation',
#  'cD4e7mq9': 'Department of Electronic Science and Technology',
#  '22Tk7XSk': 'The Synergetic Innovation Center of Chemistry and Chemical Engineering of Tianjin',
#  'l3Eq1zb5': '',
#  'EdFrCL5M': 'School of Information Science and Engineering',
#  '9fNzAyUx': 'Chinese National Engineering Laboratory for Information Security Technologies',
#  '90ONEK5l': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'lUuqOzwx': 'Dept. of Electron. Sci. and Technol.',
#  'RGo9jcH1': '',
#  'ViQkdbLY': 'Department of Neurology',
#  'tMP4yYjQ': 'Lab. of Networking and Switching',
#  'rP4wFDNz': 'Department of Computing, Imperial College London',
#  'WNpQ9KUL': 'Department of Electronic Science and Technology',
#  'sdryIbeQ': 'Institute of Surveying and Mapping',
#  'APIk8oID': 'Multi-Phase Reaction Lab.',
#  'usYoDonQ': 'Key Laboratory of Specially Functional Materials (Ministry of Education)',
#  'Rn0XkwUB': 'Department of Epidemiology and Biostatistics',
#  'f6yu8vpR': 'Department of Electronics and Information Engineering',
#  '8ajPeO3B': 'State Key Laboratory of Multiphase Complex Systems, Institute of Process Engineering, Chinese Academy of Sciences',
#  'TjzLKVUf': 'Accounting Education Department',
#  'weOdKb66': 'Institute of Computing Technology',
#  'KYLz3MMn': 'Department of Electronic Science and Technology',
#  '4vVJMLnr': 'China National Engineering Research Centre',
#  'M8igXBO6': 'Department of Neurology',
#  '6FyuMVPE': 'Information Intelligence and Information Security Center',
#  'DMp3bZ7k': '',
#  'VypQ9qJe': '',
#  'saq73SMR': 'Department of Computer',
#  'wp0EA9zB': 'Institute of Computing Technology',
#  'tsxJKrWJ': '',
#  'D3jkWlew': 'Institute of Information Science and Engineering',
#  'eSdEbqVC': 'School of Biomedical Engineering, Southern Medical University',
#  'Lm2bNYQI': 'Department of Epidemiology and Biostatistics, School of Public Health, Nanjing Medical University',
#  'zAL1nExQ': 'Key Lab. of Universal Wireless Communications',
#  'PhefL4S1': '',
#  '4zNBjocz': '',
#  '6yEWV3Mx': 'Dongling School of Economics and Management, University of Science and Technology Beijing',
#  '8IrsC8Ng': 'Institute of Computing Technology',
#  'D5oCwghX': 'Key Laboratory of Smart Grid',
#  'ynk8AiXe': 'School of Information Science and Engineering',
#  '2I0S35o2': 'Key Laboratory for Advanced Materials, Research Institute of Industrial Catalysis, East China University of Science and Technology',
#  'M5VtrUGB': 'Institute of Computing Technology',
#  '84iQz3xI': '',
#  'VXrNVFrs': 'School of Computer Science',
#  'AkrlRNGi': 'National Engineering Laboratory for Information Security Technologies, Institute of Information Engineering, Chinese Academy of Sciences',
#  'oyrxmRbl': '',
#  'DRx4shZr': '',
#  'pp92IUaT': 'School of Mechanical Engineering, Dalian University of Technology',
#  '7RCwhWgv': 'Hunan University',
#  'WbCh1mAn': 'Key Laboratory of Smart Grid of Ministry of Education',
#  'zAOszlVg': 'Institute of Computing Technology',
#  'LQiqH4ED': 'Department of Neurology',
#  'QBBhNEK6': '',
#  'gJITbjmS': 'Department of Electronic Science and Technology',
#  'CQ6sQ7G8': 'Key Laboratory of Smart Grid of Ministry of Education',
#  'SaErR9Tk': '',
#  'Fg8bI278': 'Institute of Computing Technology',
#  '6xqnpWAw': '',
#  '6ZoHfeBn': 'National Engineering Laboratory for Information Security Technologies',
#  '0kvyyjli': 'Department of Electronic Science and Technology',
#  'HleTbcx8': 'Institute of Computing Technology',
#  'iLe2tOgN': '',
#  'QXWwF1Kk': 'Department of Epidemiology and Biostatistics',
#  'gLpzYcFT': 'Department of Electronic Science and Technology',
#  'xezVg5LU': 'Institute of Computing Technology',
#  'P8XCKvH3': 'Key Laboratory of Universal Wireless Communication',
#  'meUBihaS': 'Innovation Laboratory',
#  '0BotpEwb': 'National Engineering Laboratory for Information Security Technologies',
#  'Xu9OowSM': 'School of Mechanical Engineering',
#  'V7PGj4By': 'Shanghai Astronomical Observatory',
#  '02QJq3R0': '',
#  'rXrDobwy': 'State Key Laboratory of Multiphase Reactions',
#  'YniKuL0d': 'Key Laboratory of Smart Grid',
#  '40CAD24n': 'Department of Electronic Science and Technology',
#  '81qzfSl9': '',
#  '6RraGqaT': 'Department of Information Engineering',
#  'wdM0WEpu': 'Key Lab of Universal Wireless Communications',
#  'css1qiMV': 'Institute of Computing Technology',
#  '8IZpZQoT': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'lkuLS346': 'Department of Electronic Science and Technology',
#  'KC6JdHfO': 'Department of Electronic Science and Technology',
#  'V2XqV0Gp': '',
#  'l9CxusQm': 'College of Information Science and Technology',
#  'LOmdnlHX': '',
#  '7E2OVmH0': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'QpjeUpnc': 'College of Information Science and Engineering',
#  'dWriS7uA': '',
#  'UhOJLxlA': 'Institute of Computing Technology',
#  'kF2JNvA3': 'School of Electrical and Engineering Automation, Tianjin University',
#  'DZhlmnkk': 'Department of Electronic Science and Technology',
#  'O8sqsCxI': "College of Chemistry and Chemical Engineering, Yan'an University, Shaanxi Key Laboratory of Chemical Reaction Engineering",
#  '8sPICwWg': '',
#  '6MWpiW7s': '',
#  'K2UaopGo': 'National Engineering Laboratory for Information Security Technologies',
#  'KM70zskA': 'Cooperated Inst.',
#  'CsQAFuLB': '',
#  'jBDYO0hn': 'Institute of Computing Technology',
#  'DbUNeUOi': "Department of Pathology, First People's Hospital of Foshan",
#  'OKVFXndD': 'Department of Computer Science',
#  'Fhz4Q5J5': 'Department of Neurology',
#  'NnQZhpxq': 'Automation School',
#  'SVGKVNH9': 'Department of Electronic Science and Technology',
#  'OuNnQz1O': 'Department of Electronic Science and Technology',
#  'dEVlvIzC': 'School of Information Engineering',
#  'ErEgSh1p': 'School of Electronics and Information Engineering',
#  'QizbiEFG': 'Shanghai Astronomical Observatory',
#  '3pusC0fv': '',
#  '0fZYPESX': 'Institute of Computing Technology',
#  'KdNB7XeP': 'State Key Laboratory of Multiphase Complex Systems',
#  'OLUiSLV0': '',
#  'GROwxCaI': 'Institute of Computing Technology',
#  '7T5sEfec': 'State Key Laboratory of Microbial Resources',
#  'yObtVU7U': 'School of Electrical Engineering and Automation, Tianjin University',
#  '1kRd12VR': 'Key Laboratory of Power System Simulation and Control of Ministry of Education',
#  'Svgw20G7': 'School of Civil Engineering',
#  'LMMEMoMU': '',
#  'kqV6p0S7': 'Key Laboratory of Specially Functional Materials, Ministry of Education, South China University of Technology',
#  'zf33Ktl6': 'Key Laboratory of Multiphase Reactions',
#  '7daPdGb0': 'Department of Engineering Mechanics',
#  'r84gIMOt': 'Satellite Surveying and Mapping Application Center, National Administration of Surveying, Mapping and Geoinformation',
#  'esNklVAa': '',
#  'nWyLdUFt': 'State Key Laboratory of Bioelectronics',
#  '3RHBhDHj': 'Key Laboratory of Smart Grid of Ministry of Education (Tianjin University)',
#  'UesQJyxp': 'Department of Civil Engineering',
#  'GlRPkZqV': 'State Key Laboratory of Bioelectronics',
#  'zqRUVmVO': '',
#  '4f3rU3Hx': 'Key Laboratory of Multiphase Reactions',
#  'a9EP1XMo': 'Institute of Computing Technology',
#  'z95rFvLf': 'School of Electronic Science and Technology, Dalian University of Technology',
#  'sp08IlyR': 'Institue of Information Engineering, Chinese Academy of Science',
#  'Ivv3TQ5b': 'National Engineering Laboratory for Information Security Technologies, Institute of Information Engineering, Chinese Academy of Sciences',
#  'eVNAxM2Q': 'College of Global Change and Earth System Science, Beijing Normal University',
#  'TW81hAUl': 'College of Electric Power',
#  'ro47BLIE': 'School of Computer',
#  'pACUzJEw': 'Department of Computer Science',
#  'hq7oWIWn': '',
#  'CqGdDBRk': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'm36mX6RE': 'School of Information Science and Engineering',
#  '3T51KAeR': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'LqpZ4AkF': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'E8WCW8U8': 'Key Laboratory of Smart Grid of Ministry of Education',
#  'uWm6iIE3': 'Dept. of Electronic Science and Technology',
#  'wHg28Xap': '',
#  'NBoLIKF0': '',
#  'xSwUQG2C': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'AUWgXn9c': 'Key Laboratory of Universal Wireless Communication',
#  'NB5sXrqb': '',
#  'hwiAkAOI': 'Department of Electronic Science and Technology',
#  'NdksRx6d': 'College of Automation',
#  '1XIQkrwj': '',
#  'kf8XV8Io': 'Institute of Information Science and Engineering',
#  'vx3H8RJC': 'Inst. of Comp. Technol.',
#  '89McajsE': 'Institute of Information Science and Engineering',
#  'DLTK01Ew': 'Computer Department',
#  'KdSW1OCH': 'South China University of Technology',
#  'cXzxZU2s': 'Department of Electronic Science and Technology',
#  'QzDjkFeL': '',
#  'cYrdZMvc': 'Department of Electronic Science and Technology',
#  'hiFlRcie': 'Institute of Computing Technology',
#  'JDbml0J9': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'EWCUf5ug': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'SCnCeUS7': 'Institute of Computing Technology',
#  'Aj9i6e0J': 'Institute of Information Engineering',
#  'FMaiNqCq': 'School of Mechanical Engineering',
#  'v2iNIa5Y': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  'LG8BjE9t': 'Dept. of Electronic Science and Technology',
#  'FbDwJIos': 'National Engineering Laboratory for Information Security Technologies',
#  'yMC8cM2f': 'Institute of Information Engineering, Chinese Academy of Science 10093',
#  'PRvOotSf': '',
#  'HehGxPXo': 'Department of Electronic Science and Technology',
#  '66e1Tc2L': 'Institute of Information Engineering',
#  'SmET5rpv': 'Information Engineering Department',
#  'fHIzNpAv': 'Key Lab of Universal Wireless Communications, Ministry of Education, Beijing University of Posts and Telecommunications',
#  'MeCB79RI': 'The Department of Neurology of the Second Hospital of Hebei Medical University',
#  'WJt3jOWF': 'Key Laboratory of Power System Simulation and Control of Ministry of Education',
#  'gli7y2IS': 'Key Lab of Universal Wireless Communications, Ministry of Education, Beijing University of Posts and Telecommunications',
#  'c7rFqRZ9': 'Department of Neurology',
#  'oHCT8cpU': 'Graduate University',
#  'FDWPKjCe': 'Institute of Computing Technology',
#  'pKlc5zx1': 'State Key Laboratory of Nonlinear Mechanics',
#  'SAd2ZtaQ': 'Key Laboratory of Power System Simulation and Control of Ministry of Education',
#  'bIyTD7ie': 'State Key Laboratory of Microbial Resources',
#  'joH1S56U': 'Key Laboratory of Universa LWireless Communication',
#  'dsDD4Gem': 'School of Information Science and Technology',
#  'sFbVl6Nx': '',
#  '5CDB0eUZ': 'State Key Laboratory of Multi-phase Complex Systems',
#  'cfqLUCoP': 'State Key Laboratory of Bioelectronics',
#  'AmTDyDtu': 'Department of Neurology',
#  'eqwoV7YF': 'Key Laboratory for Quantum Optics',
#  'SnLukQny': 'Key Laboratory of Information Processing and Intelligent Technology',
#  '3M3xxkd0': 'Department of Epidemiology and Biostatistics',
#  'kut768z8': 'Institute of Information Engineering, Chinese Academy of Sciences',
#  '8lMWtfxb': 'Institute of Computing Technology',
#  'Y2EMcZu3': 'Department of Epidemiology and Biostatistics and Ministry of Education Key Lab for Modern Toxicology, School of Public Health, Nanjing Medical University',
#  'JLhtZYlV': 'Key Laboratory of Smart Grid of Ministry of Education',
#  'NovH9MO4': 'LNM',
#  'cUaeeIxi': 'Graduate University',
#  'lbaC135x': 'College of Information Engineering, Hubei University for Nationalities',
#  ...}

# %%
author_org_map['li_guo']['UG32p2zs']
# Out:
# 'West China School of Pharmacy'

# %%
author_id_org_map['sCKCrny5']
# Out:
# ['Department of Medicinal Chemistry',
#  '',
#  'Department of Medicinal Chemistry',
#  'Key Laboratory of Drug Targeting and Drug Delivery System',
#  'West China School of Pharmacy',
#  'Key Laboratory of Drug Targeting and Drug Delivery System of Education Ministry, Department of Medicinal Chemistry, West China School of Pharmacy, Sichuan University',
#  'Key Laboratory of Drug-Targeting of Education Ministry and Department of Medicinal Chemistry, West China School of Pharmacy, Sichuan University',
#  'Key Laboratory of Drug Targeting and Drug Delivery System of the Education Ministry, Department of Medicinal Chemistry, West China School of Pharmacy, Sichuan University',
#  'Dept. of Pharmaceutical Chemistry',
#  'Key Laboratory of Drug Targeting of Ministry of Education',
#  'Key Laboratory of Drug Targeting of Education Ministry',
#  'West China School of Pharmacy',
#  'Department of Chemical Engineering',
#  'Department of Medicinal Chemistry',
#  'Key Laboratory of Drug Targeting and Drug Delivery Systems, West China School of Pharmacy, Sichuan University',
#  'West China School of Pharmacy',
#  'Key Laboratory of Drug Targeting and Drug Delivery Systems',
#  'Department of Medicinal Chemistry',
#  '',
#  'Key Laboratory of Drug Targeting and Drug Delivery System of Education Ministry',
#  'Laboratory of Transplant Engineering and Immunology',
#  'Sichuan Union University',
#  'Department of Medicinal Chemistry, West China School of Pharmacy, Sichuan University',
#  'Department of Medicinal Chemistry',
#  'Department of Medicinal Chemistry',
#  '',
#  'Key Laboratory of Drug-Targeting of Education Ministry and Department of Medicinal Chemistry',
#  'West China School of Pharmacy',
#  'Department of Medicinal Chemistry',
#  'Key Laboratory of Transplant Engineering and Immunology',
#  '',
#  'West China School of Pharmacy',
#  'Department of Medicinal Chemistry',
#  'Key Laboratory of Drug Targeting of Ministry of Education',
#  'West China Medical Center',
#  'Department of Biomedical Engineering',
#  'Department of Medicinal Chemistry',
#  '',
#  'Department of Biomedical Engineering',
#  'State Key Laboratory of Biotherapy',
#  'Key Laboratory of Drug Targeting of Education Ministry, West China School of Pharmacy, Sichuan University',
#  '',
#  'Key Laboratory of Drug Targeting and Drug Delivery Systems',
#  'Key Laboratory of Drug Targeting and Drug Delivery Systems, West China School of Pharmacy, Sichuan University',
#  'Key Laboratory of Drug Targeting of Ministry of Education',
#  'Department of Medicinal Chemistry',
#  'West China School of Pharmacy, Sichuan University',
#  'West China School of Pharmacy']

# %%
with open('./pkl/author_org_map.pkl', 'wb') as file:
    pickle.dump(author_org_map, file)

# %%
author_id_org_map_df = pd.DataFrame()
author_id_org_map_df['author_id'] = author_id_org_map.keys()
author_id_org_map_df['orgs'] = author_id_org_map.values()
author_id_org_map_df['orgs'] = author_id_org_map_df['orgs']
author_id_org_map_df.head()
# Out:
#   author_id                                               orgs
# 0  004mBKh6  [, Department of Biomedical Engineering, Natio...
# 1  008b5hIc  [State Key Laboratory Breeding Base of Nuclear...
# 2  00BAgHFr  [, , School of Information System and Management]
# 3  00M93JDI  [None, None, None, academia sinica, None, None...
# 4  00ShLPmg  [.Department of Microbiology and Immunology,Gu...

# %%
len(author_id_org_map_df)
# Out:
# 25911

# %%
author_id_org_map_df.to_pickle('./pkl/author_id_org_map.pkl')
